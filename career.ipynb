# %%
#Data Loading and Inspection
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('career.csv') 
df
# Out:
#      user_id              name   age education_level    field_of_study  \
# 0     U00001               NaN   NaN     High School               NaN
# 1     U00002               NaN   NaN     High School  Computer Science
# 2     U00003       Anika Patel  24.0        Graduate        Psychology
# 3     U00004     Joseph Sharma  27.0     High School        Psychology
# 4     U00005        Anika Iyer  23.0        Graduate                IT
# ...      ...               ...   ...             ...               ...
# 7094  U07095        Emma Brown  27.0        Graduate             Other
# 7095  U07096    William Martin  25.0        Graduate             Other
# 7096  U07097    David Thompson  29.0   Undergraduate             Other
# 7097  U07098    James Thompson  25.0     High School             Other
# 7098  U07099  William Thompson  25.0     High School             Other
#
#      experience_years  openness  conscientiousness  extraversion  \
# 0             1 years       4.0                NaN           2.0
# 1             0 years       5.0                3.0           3.0
# 2             0 years       2.0                4.0           3.0
# 3             2 years       3.0                3.0           3.0
# 4             3 years       1.0                4.0           3.0
# ...               ...       ...                ...           ...
# 7094          0 years       2.0                1.0           4.0
# 7095          3 years       3.0                2.0           4.0
# 7096          2 years       4.0                3.0           5.0
# 7097          1 years       5.0                3.0           5.0
# 7098          5 years       2.0                1.0           5.0
#
#       agreeableness  ...  creative_thinking_skill  interest_technology  \
# 0               3.0  ...                      3.0                 15.0
# 1               2.0  ...                      2.0                 53.0
# 2               4.0  ...                      3.0                 17.0
# 3               4.0  ...                      2.0                 55.0
# 4               3.0  ...                      2.0                 34.0
# ...             ...  ...                      ...                  ...
# 7094            3.0  ...                      5.0                 65.0
# 7095            5.0  ...                      2.0                 36.0
# 7096            3.0  ...                      3.0                 23.0
# 7097            3.0  ...                      1.0                 90.0
# 7098            2.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 0                  32.0               39.0                    24.0
# 1                  39.0               74.0                    52.0
# 2                  43.0               81.0                    29.0
# 3                  83.0               33.0                    45.0
# 4                  54.0               38.0                    32.0
# ...                 ...                ...                     ...
# 7094               99.0               98.0                    12.0
# 7095               40.0               76.0                    43.0
# 7096               42.0               10.0                    41.0
# 7097               72.0               33.0                    86.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 0                           49.0            individual             structured
# 1                           26.0            individual               flexible
# 2                           54.0         collaborative               flexible
# 3                           68.0            individual               flexible
# 4                           52.0         collaborative             structured
# ...                          ...                   ...                    ...
# 7094                        95.0            individual             structured
# 7095                        33.0         collaborative               flexible
# 7096                        96.0            individual               flexible
# 7097                        34.0            individual             structured
# 7098                        78.0            individual             structured
#
#       risk_tolerance                career_cluster
# 0                NaN     Education & Social Impact
# 1                low       Design & Creative Media
# 2                low       Design & Creative Media
# 3             medium         Business & Management
# 4               high    Healthcare & Life Sciences
# ...              ...                           ...
# 7094            high         Business & Management
# 7095            high  Entrepreneurship & Freelance
# 7096          medium           Finance & Economics
# 7097          medium     Education & Social Impact
# 7098             low      Technology & Engineering
#
# [7099 rows x 26 columns]

# %%
print(df.shape)
# Out:
# (7099, 26)

# %%
print(df.columns)
# Out:
# Index(['user_id', 'name', 'age', 'education_level', 'field_of_study',
#        'experience_years', 'openness', 'conscientiousness', 'extraversion',
#        'agreeableness', 'neuroticism', 'technical_skill',
#        'data_reasoning_skill', 'communication_skill', 'problem_solving_skill',
#        'leadership_skill', 'creative_thinking_skill', 'interest_technology',
#        'interest_business', 'interest_creative', 'interest_health_social',
#        'interest_research_academic', 'preferred_work_style',
#        'preferred_environment', 'risk_tolerance', 'career_cluster'],
#       dtype='object')

# %%
print(df.head())
# Out:
#   user_id           name   age education_level    field_of_study  \
# 0  U00001            NaN   NaN     High School               NaN
# 1  U00002            NaN   NaN     High School  Computer Science
# 2  U00003    Anika Patel  24.0        Graduate        Psychology
# 3  U00004  Joseph Sharma  27.0     High School        Psychology
# 4  U00005     Anika Iyer  23.0        Graduate                IT
#
#   experience_years  openness  conscientiousness  extraversion  agreeableness  \
# 0          1 years       4.0                NaN           2.0            3.0
# 1          0 years       5.0                3.0           3.0            2.0
# 2          0 years       2.0                4.0           3.0            4.0
# 3          2 years       3.0                3.0           3.0            4.0
# 4          3 years       1.0                4.0           3.0            3.0
#
#    ...  creative_thinking_skill  interest_technology  interest_business  \
# 0  ...                      3.0                 15.0               32.0
# 1  ...                      2.0                 53.0               39.0
# 2  ...                      3.0                 17.0               43.0
# 3  ...                      2.0                 55.0               83.0
# 4  ...                      2.0                 34.0               54.0
#
#    interest_creative  interest_health_social  interest_research_academic  \
# 0               39.0                    24.0                        49.0
# 1               74.0                    52.0                        26.0
# 2               81.0                    29.0                        54.0
# 3               33.0                    45.0                        68.0
# 4               38.0                    32.0                        52.0
#
#    preferred_work_style  preferred_environment  risk_tolerance  \
# 0            individual             structured             NaN
# 1            individual               flexible             low
# 2         collaborative               flexible             low
# 3            individual               flexible          medium
# 4         collaborative             structured            high
#
#                career_cluster
# 0   Education & Social Impact
# 1     Design & Creative Media
# 2     Design & Creative Media
# 3       Business & Management
# 4  Healthcare & Life Sciences
#
# [5 rows x 26 columns]

# %%
print(df.tail())
# Out:
#      user_id              name   age education_level field_of_study  \
# 7094  U07095        Emma Brown  27.0        Graduate          Other
# 7095  U07096    William Martin  25.0        Graduate          Other
# 7096  U07097    David Thompson  29.0   Undergraduate          Other
# 7097  U07098    James Thompson  25.0     High School          Other
# 7098  U07099  William Thompson  25.0     High School          Other
#
#      experience_years  openness  conscientiousness  extraversion  \
# 7094          0 years       2.0                1.0           4.0
# 7095          3 years       3.0                2.0           4.0
# 7096          2 years       4.0                3.0           5.0
# 7097          1 years       5.0                3.0           5.0
# 7098          5 years       2.0                1.0           5.0
#
#       agreeableness  ...  creative_thinking_skill  interest_technology  \
# 7094            3.0  ...                      5.0                 65.0
# 7095            5.0  ...                      2.0                 36.0
# 7096            3.0  ...                      3.0                 23.0
# 7097            3.0  ...                      1.0                 90.0
# 7098            2.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 7094               99.0               98.0                    12.0
# 7095               40.0               76.0                    43.0
# 7096               42.0               10.0                    41.0
# 7097               72.0               33.0                    86.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 7094                        95.0            individual             structured
# 7095                        33.0         collaborative               flexible
# 7096                        96.0            individual               flexible
# 7097                        34.0            individual             structured
# 7098                        78.0            individual             structured
#
#       risk_tolerance                career_cluster
# 7094            high         Business & Management
# 7095            high  Entrepreneurship & Freelance
# 7096          medium           Finance & Economics
# 7097          medium     Education & Social Impact
# 7098             low      Technology & Engineering
#
# [5 rows x 26 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7099 entries, 0 to 7098
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user_id                     6980 non-null   object
#  1   name                        7000 non-null   object
#  2   age                         7007 non-null   float64
#  3   education_level             7020 non-null   object
#  4   field_of_study              7016 non-null   object
#  5   experience_years            7023 non-null   object
#  6   openness                    7006 non-null   float64
#  7   conscientiousness           6999 non-null   float64
#  8   extraversion                7007 non-null   float64
#  9   agreeableness               7017 non-null   float64
#  10  neuroticism                 6999 non-null   float64
#  11  technical_skill             7007 non-null   float64
#  12  data_reasoning_skill        7005 non-null   float64
#  13  communication_skill         7015 non-null   float64
#  14  problem_solving_skill       6995 non-null   float64
#  15  leadership_skill            7001 non-null   float64
#  16  creative_thinking_skill     7009 non-null   float64
#  17  interest_technology         7018 non-null   float64
#  18  interest_business           6999 non-null   float64
#  19  interest_creative           7017 non-null   float64
#  20  interest_health_social      6999 non-null   float64
#  21  interest_research_academic  7010 non-null   float64
#  22  preferred_work_style        7021 non-null   object
#  23  preferred_environment       6994 non-null   object
#  24  risk_tolerance              6999 non-null   object
#  25  career_cluster              7099 non-null   object
# dtypes: float64(17), object(9)
# memory usage: 1.4+ MB
# None

# %%
df.dtypes
# Out:
# user_id                        object
# name                           object
# age                           float64
# education_level                object
# field_of_study                 object
# experience_years               object
# openness                      float64
# conscientiousness             float64
# extraversion                  float64
# agreeableness                 float64
# neuroticism                   float64
# technical_skill               float64
# data_reasoning_skill          float64
# communication_skill           float64
# problem_solving_skill         float64
# leadership_skill              float64
# creative_thinking_skill       float64
# interest_technology           float64
# interest_business             float64
# interest_creative             float64
# interest_health_social        float64
# interest_research_academic    float64
# preferred_work_style           object
# preferred_environment          object
# risk_tolerance                 object
# career_cluster                 object
# dtype: object

# %%
df[['openness','conscientiousness','extraversion','agreeableness','neuroticism']].describe()
# Out:
#           openness  conscientiousness  extraversion  agreeableness  \
# count  7006.000000        6999.000000   7007.000000    7017.000000
# mean      3.611904           3.613373      2.668046       3.611087
# std       0.984662           0.977000      0.971465       0.983737
# min       1.000000           1.000000      1.000000       1.000000
# 25%       3.000000           3.000000      2.000000       3.000000
# 50%       4.000000           4.000000      3.000000       4.000000
# 75%       4.000000           4.000000      3.000000       4.000000
# max       5.000000           5.000000      5.000000       5.000000
#
#        neuroticism
# count  6999.000000
# mean      2.369338
# std       0.980101
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       5.000000

# %%
df[['technical_skill', 'data_reasoning_skill', 'communication_skill',
    'problem_solving_skill', 'leadership_skill', 'creative_thinking_skill']].describe()
# Out:
#        technical_skill  data_reasoning_skill  communication_skill  \
# count      7007.000000           7005.000000          7015.000000
# mean          2.406451              2.655960             2.935139
# std           1.167430              1.313771             1.204230
# min           0.000000              0.000000             0.000000
# 25%           2.000000              2.000000             2.000000
# 50%           2.000000              3.000000             3.000000
# 75%           3.000000              4.000000             4.000000
# max           5.000000              5.000000             5.000000
#
#        problem_solving_skill  leadership_skill  creative_thinking_skill
# count            6995.000000       7001.000000              7009.000000
# mean                3.498213          2.650193                 2.641746
# std                 0.892309          1.014349                 1.007210
# min                 0.000000          0.000000                 0.000000
# 25%                 3.000000          2.000000                 2.000000
# 50%                 4.000000          3.000000                 3.000000
# 75%                 4.000000          3.000000                 3.000000
# max                 5.000000          5.000000                 5.000000

# %%
df[['interest_technology', 'interest_business', 'interest_creative', 
    'interest_health_social', 'interest_research_academic']].describe()
# Out:
#        interest_technology  interest_business  interest_creative  \
# count          7018.000000        6999.000000        7017.000000
# mean             48.943716          53.480783          44.651275
# std              18.604947          20.779766          20.659804
# min               0.000000           5.000000           0.000000
# 25%              35.000000          35.000000          30.000000
# 50%              45.000000          52.000000          40.000000
# 75%              60.000000          71.000000          52.000000
# max             100.000000         101.000000         100.000000
#
#        interest_health_social  interest_research_academic
# count             6999.000000                 7010.000000
# mean                40.043578                   47.655064
# std                 19.269162                   16.132574
# min                  0.000000                    0.000000
# 25%                 26.000000                   37.000000
# 50%                 36.000000                   46.000000
# 75%                 51.000000                   60.000000
# max                 99.000000                  100.000000

# %%
#Converting to integer type.
df['experience_years']=df['experience_years'].str.replace("years","").astype('Int64')
df['experience_years']
# Out:
# 0       1
# 1       0
# 2       0
# 3       2
# 4       3
#        ..
# 7094    0
# 7095    3
# 7096    2
# 7097    1
# 7098    5
# Name: experience_years, Length: 7099, dtype: Int64

# %%
#Dropping useless columns
df.drop(columns=['user_id','name'], inplace=True)

# %%
# Map categorical risk tolerance levels to numerical values
df['risk_tolerance']=df['risk_tolerance'].map({'low':0, 'medium':1, 'high':2})
df['risk_tolerance'].dtype
# Out:
# dtype('float64')

# %%
#Checking for missing values
df.isna().sum()
# Out:
# age                            92
# education_level                79
# field_of_study                 83
# experience_years               76
# openness                       93
# conscientiousness             100
# extraversion                   92
# agreeableness                  82
# neuroticism                   100
# technical_skill                92
# data_reasoning_skill           94
# communication_skill            84
# problem_solving_skill         104
# leadership_skill               98
# creative_thinking_skill        90
# interest_technology            81
# interest_business             100
# interest_creative              82
# interest_health_social        100
# interest_research_academic     89
# preferred_work_style           78
# preferred_environment         105
# risk_tolerance                100
# career_cluster                  0
# dtype: int64

# %%
#Printing unique values in features.
l = ['age','education_level','field_of_study', 'experience_years', 'openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism', 'technical_skill', 'data_reasoning_skill', 'communication_skill', 'problem_solving_skill', 'leadership_skill', 'creative_thinking_skill', 'interest_technology', 'interest_business', 'interest_creative', 'interest_health_social', 'interest_research_academic', 'preferred_work_style', 'preferred_environment', 'risk_tolerance']
for i in l:
    print(i, ":", df[i].unique(), "\n")
# Out:
# age : [nan 24. 27. 23. 21. 25. 30. 20. 18. 22. 26. 28. 40. 19. 29. 15. 35.]
#
# education_level : ['High School' 'Graduate' 'Undergraduate' nan]
#
# field_of_study : [nan 'Computer Science' 'Psychology' 'IT' 'Design' 'Biology' 'Business'
#  'Economics' 'Engineering' 'Other']
#
# experience_years : <IntegerArray>
# [1, 0, 2, 3, <NA>, 4, 5, 9, 6, 7, 8, 10]
# Length: 12, dtype: Int64
#
# openness : [ 4.  5.  2.  3.  1. nan]
#
# conscientiousness : [nan  3.  4.  2.  5.  1.]
#
# extraversion : [ 2.  3.  1.  4.  5. nan]
#
# agreeableness : [ 3.  2.  4.  5.  1. nan]
#
# neuroticism : [nan  2.  3.  1.  5.  4.]
#
# technical_skill : [ 2.  1.  0.  3. nan  4.  5.]
#
# data_reasoning_skill : [ 1.  0.  3.  2.  4.  5. nan]
#
# communication_skill : [nan  3.  2.  1.  4.  5.  0.]
#
# problem_solving_skill : [ 3.  4.  5.  2.  0. nan  1.]
#
# leadership_skill : [ 2.  4.  3. nan  5.  1.  0.]
#
# creative_thinking_skill : [ 3.  2.  4.  1.  5.  0. nan]
#
# interest_technology : [ 15.  53.  17.  55.  34.  46.  35.  47.  39.  68.  22.  51.  66.  28.
#   42.  nan  31.  49.  44.  84.  85.  86.  37.  21.  25.  71.  29.  24.
#   92.  27.  91.  73.  64.  41.  76.  57.  50.  78.  58.  23.  74.  45.
#   56.  83.  20.  59.  30.  61.  54.  69.  38.  75.  33.  81. 100.  52.
#   48.  72.  43.  67.  79.  90.  60.  77.  16.  32.  40.  26.  63.  36.
#   70.  18.  97.   6.  65.  62.  80.  19.  82.   9.  93.  89.  96.  87.
#   88.  14.  98.  11.   8.  13.  94.  95.  10.   7.  99.   0.  12.]
#
# interest_business : [ 32.  39.  43.  83.  54.  73.  94.  67.  38.  65.  51.  57.  91.  61.
#   52.  75.  44.  64.  71.  26.  47.  55.  nan  48.  63.  49.  40.  66.
#   30.  42.  79.  41.  60.  82.  35.  53.  74.  50.  72.  56.  85.  88.
#   33.  70.  62.  19.  34.  80.  78.  68.  76.  77.  45.  36.  37.  59.
#   86.  58.  15.  27.  21.  92.  84.  69.  28. 100.  97.  31.  46.  99.
#   23.  29.  87.  22.  96.  81.  90.  16.  89.  18.  25.   5.  24.  95.
#   93.  20.  10.  13.  11.   7.  98. 101.  12.]
#
# interest_creative : [ 39.  74.  81.  33.  38.  34.  25.  68.  51.  69.  nan  41.  57.  89.
#   15.  35.  79.  52.  37.  53.  23.  17.  42. 100.  92.  26.  82.  30.
#   59.  83.  32.  36.  49.  45.  24.  58.  87.  20.  93.  48.  56.  40.
#   50.  84.  44.  76.  90.  71.  46.  28.  12.  60.  77.  27.  47.  95.
#   70.  31.  21.  66.  43.  29.  72.  13.  86.  62.  18.  80.  19.  22.
#   61.  63.  78.  10.  73.  91.  75.  64.  85.  54.  94.  55.  14.  65.
#   88.   8.  99.  98.  96.   9.  16.  97.  67.  11.   5.   6.   0.   1.
#    7.]
#
# interest_health_social : [24. 52. 29. 45. 32. 68. 48. 15. 25. 36. nan 35. 40. 21. 33. 37. 39. 27.
#  44. 53. 57. 16. 22. 49. 28. 19. 14. 55. 47.  0. 34. 43. 46. 58. 63. 42.
#  77. 41. 65. 56. 51. 62. 64. 74. 60. 31. 38. 26. 18.  7. 30. 23. 71. 61.
#  59. 13. 17. 69. 54. 50.  8. 12. 20.  9. 10. 11. 72.  4. 66.  6. 78. 90.
#  89. 75. 79. 70.  5. 81. 73. 67. 80.  1.  3.  2. 76. 82. 88. 91. 85. 83.
#  98. 95. 93. 96. 97. 86. 92. 87. 94. 99. 84.]
#
# interest_research_academic : [ 49.  26.  54.  68.  52.  47.  77.  56.  85.  35.  58.  46.  53.  76.
#   48.  32.  37.  64.  14.  29.  23.  36.  38.  11.  50.  44.  61.  60.
#   59.  84.  31.  71.  66.  34.  45.  nan   2.  57.  15.  51.  12.  41.
#   43.  63.  55.  42.  28.  40.  65.  62.  39.  69.  33.  30.  70.  27.
#   72.  24.  74.  25.  75.  18.  20.   8.  21.  83.   7.   6.  13.  78.
#   67.  19.  22.  79.  81.   9.  17.  16.   4.  73.  80.   5.  82.   3.
#    1.  10.   0.  87.  89.  86.  97.  93.  94.  92.  96. 100.  95.]
#
# preferred_work_style : ['individual' 'collaborative' nan]
#
# preferred_environment : ['structured' 'flexible' nan]
#
# risk_tolerance : [nan  0.  1.  2.]

# %%
#Filling missing values
median_cols = [
    'age', 'experience_years', 'openness', 'conscientiousness',
    'extraversion', 'agreeableness', 'neuroticism',
    'technical_skill', 'data_reasoning_skill', 'communication_skill',
    'problem_solving_skill', 'leadership_skill', 'creative_thinking_skill',
    'interest_technology', 'interest_business', 'interest_creative',
    'interest_health_social', 'interest_research_academic'
]

for col in median_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
mode_cols = [
    'education_level', 'field_of_study',
    'preferred_work_style', 'preferred_environment',
    'risk_tolerance'
]

for col in mode_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
#IQR
num_cols = df.select_dtypes(include=['int64','float64']).columns
outlier_len = {}
for i in num_cols:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1 
    outliers = df[(df[i] < Q1 - 1.5*IQR) | (df[i] > Q3 + 1.5*IQR)]
    outlier_len[i] = len(outliers)
outlier_len
# Out:
#        age education_level    field_of_study  experience_years  openness  \
# 50    40.0   Undergraduate                IT                 1       4.0
# 64    40.0     High School         Economics                 0       5.0
# 451   40.0   Undergraduate        Psychology                 2       5.0
# 504   40.0        Graduate                IT                 3       5.0
# 657   40.0        Graduate            Design                 1       3.0
# ...    ...             ...               ...               ...       ...
# 4702  40.0   Undergraduate          Business                 1       4.0
# 4723  40.0        Graduate        Psychology                 1       5.0
# 4800  40.0        Graduate  Computer Science                 0       3.0
# 4824  40.0     High School            Design                 2       4.0
# 4872  40.0        Graduate                IT                 0       3.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 50                  5.0           3.0            4.0          1.0
# 64                  5.0           2.0            5.0          3.0
# 451                 2.0           3.0            3.0          2.0
# 504                 5.0           2.0            2.0          1.0
# 657                 4.0           2.0            3.0          3.0
# ...                 ...           ...            ...          ...
# 4702                3.0           2.0            5.0          3.0
# 4723                5.0           4.0            3.0          3.0
# 4800                3.0           4.0            4.0          1.0
# 4824                2.0           4.0            4.0          1.0
# 4872                2.0           1.0            5.0          2.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 50                2.0  ...                      3.0                 50.0
# 64                1.0  ...                      4.0                 59.0
# 451               3.0  ...                      2.0                 65.0
# 504               2.0  ...                      4.0                 75.0
# 657               0.0  ...                      4.0                 41.0
# ...               ...  ...                      ...                  ...
# 4702              2.0  ...                      2.0                 39.0
# 4723              1.0  ...                      3.0                 63.0
# 4800              2.0  ...                      4.0                 20.0
# 4824              0.0  ...                      4.0                 43.0
# 4872              4.0  ...                      4.0                 81.0
#
#       interest_business  interest_creative  interest_health_social  \
# 50                 39.0               87.0                    49.0
# 64                 63.0               50.0                    48.0
# 451                67.0               73.0                    17.0
# 504                60.0               54.0                    38.0
# 657                50.0               25.0                    51.0
# ...                 ...                ...                     ...
# 4702               47.0               44.0                    27.0
# 4723               41.0               66.0                    40.0
# 4800               61.0               66.0                    36.0
# 4824               34.0               90.0                    36.0
# 4872               41.0               32.0                    44.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 50                          47.0         collaborative               flexible
# 64                          57.0         collaborative               flexible
# 451                         43.0            individual               flexible
# 504                         36.0         collaborative             structured
# 657                         37.0            individual             structured
# ...                          ...                   ...                    ...
# 4702                        41.0         collaborative             structured
# 4723                        36.0            individual             structured
# 4800                        31.0         collaborative               flexible
# 4824                        54.0            individual               flexible
# 4872                        68.0         collaborative             structured
#
#       risk_tolerance                career_cluster
# 50               2.0       Design & Creative Media
# 64               1.0     Education & Social Impact
# 451              1.0  Entrepreneurship & Freelance
# 504              2.0      Technology & Engineering
# 657              0.0    Healthcare & Life Sciences
# ...              ...                           ...
# 4702             1.0    Healthcare & Life Sciences
# 4723             2.0  Entrepreneurship & Freelance
# 4800             0.0     Education & Social Impact
# 4824             2.0       Design & Creative Media
# 4872             1.0      Technology & Engineering
#
# [68 rows x 24 columns]
#        age education_level field_of_study  experience_years  openness  \
# 47    24.0        Graduate     Psychology                 4       3.0
# 83    28.0   Undergraduate        Biology                 4       5.0
# 113   27.0        Graduate       Business                 4       4.0
# 128   29.0   Undergraduate             IT                 5       4.0
# 140   24.0   Undergraduate         Design                 4       4.0
# ...    ...             ...            ...               ...       ...
# 7081  20.0        Graduate          Other                 5       4.0
# 7085  30.0        Graduate          Other                 5       5.0
# 7089  24.0     High School          Other                 6       2.0
# 7092  29.0   Undergraduate          Other                 6       4.0
# 7098  25.0     High School          Other                 5       2.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 47                  3.0           2.0            3.0          2.0
# 83                  5.0           4.0            4.0          3.0
# 113                 3.0           2.0            2.0          2.0
# 128                 3.0           3.0            4.0          2.0
# 140                 3.0           3.0            4.0          3.0
# ...                 ...           ...            ...          ...
# 7081                1.0           2.0            1.0          2.0
# 7085                2.0           2.0            4.0          5.0
# 7089                3.0           5.0            3.0          2.0
# 7092                5.0           4.0            2.0          5.0
# 7098                1.0           5.0            2.0          4.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 47                4.0  ...                      2.0                 66.0
# 83                1.0  ...                      3.0                 44.0
# 113               3.0  ...                      3.0                 79.0
# 128               4.0  ...                      3.0                 53.0
# 140               3.0  ...                      3.0                 50.0
# ...               ...  ...                      ...                  ...
# 7081              3.0  ...                      5.0                 24.0
# 7085              1.0  ...                      2.0                 25.0
# 7089              2.0  ...                      3.0                 68.0
# 7092              5.0  ...                      2.0                 55.0
# 7098              4.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 47                 67.0               39.0                    63.0
# 83                 50.0               59.0                    22.0
# 113                36.0               36.0                    52.0
# 128                59.0               43.0                    46.0
# 140                60.0               52.0                    54.0
# ...                 ...                ...                     ...
# 7081               91.0               62.0                    52.0
# 7085               46.0               95.0                    33.0
# 7089                7.0               16.0                    55.0
# 7092               83.0               99.0                    43.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 47                          71.0         collaborative             structured
# 83                          42.0         collaborative             structured
# 113                         31.0         collaborative             structured
# 128                         56.0         collaborative             structured
# 140                         58.0            individual               flexible
# ...                          ...                   ...                    ...
# 7081                        52.0         collaborative             structured
# 7085                        49.0         collaborative             structured
# 7089                        69.0         collaborative             structured
# 7092                        80.0         collaborative               flexible
# 7098                        78.0            individual             structured
#
#       risk_tolerance                career_cluster
# 47               0.0  Entrepreneurship & Freelance
# 83               0.0     Education & Social Impact
# 113              0.0      Technology & Engineering
# 128              1.0  Entrepreneurship & Freelance
# 140              1.0  Entrepreneurship & Freelance
# ...              ...                           ...
# 7081             2.0  Entrepreneurship & Freelance
# 7085             1.0       Design & Creative Media
# 7089             0.0           Finance & Economics
# 7092             2.0       Design & Creative Media
# 7098             0.0      Technology & Engineering
#
# [710 rows x 24 columns]
#        age education_level    field_of_study  experience_years  openness  \
# 4     23.0        Graduate                IT                 3       1.0
# 13    30.0   Undergraduate  Computer Science                 2       1.0
# 37    23.0     High School                IT                 3       1.0
# 95    27.0     High School                IT                 1       1.0
# 175   26.0        Graduate                IT                 1       1.0
# ...    ...             ...               ...               ...       ...
# 7059  26.0        Graduate             Other                 2       1.0
# 7061  20.0        Graduate             Other                 5       1.0
# 7071  19.0   Undergraduate             Other                 6       1.0
# 7077  24.0   Undergraduate             Other                 2       1.0
# 7093  18.0   Undergraduate             Other                 2       1.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 4                   4.0           3.0            3.0          3.0
# 13                  4.0           2.0            4.0          2.0
# 37                  5.0           4.0            1.0          2.0
# 95                  4.0           2.0            4.0          3.0
# 175                 3.0           3.0            2.0          1.0
# ...                 ...           ...            ...          ...
# 7059                4.0           3.0            4.0          1.0
# 7061                1.0           5.0            2.0          4.0
# 7071                5.0           5.0            5.0          1.0
# 7077                3.0           1.0            3.0          2.0
# 7093                4.0           5.0            3.0          1.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 4                 0.0  ...                      2.0                 34.0
# 13                1.0  ...                      2.0                 28.0
# 37                3.0  ...                      3.0                 92.0
# 95                4.0  ...                      3.0                 86.0
# 175               2.0  ...                      2.0                 33.0
# ...               ...  ...                      ...                  ...
# 7059              3.0  ...                      5.0                 69.0
# 7061              4.0  ...                      3.0                 97.0
# 7071              3.0  ...                      2.0                 25.0
# 7077              1.0  ...                      3.0                 74.0
# 7093              5.0  ...                      2.0                 97.0
#
#       interest_business  interest_creative  interest_health_social  \
# 4                  54.0               38.0                    32.0
# 13                 57.0               89.0                    21.0
# 37                 47.0               23.0                    32.0
# 95                 30.0               45.0                    31.0
# 175                33.0               17.0                    34.0
# ...                 ...                ...                     ...
# 7059               32.0               24.0                    89.0
# 7061               46.0               77.0                    81.0
# 7071               28.0               93.0                    84.0
# 7077               48.0               87.0                    27.0
# 7093               11.0               79.0                    66.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 4                           52.0         collaborative             structured
# 13                          58.0            individual               flexible
# 37                          52.0            individual               flexible
# 95                          57.0            individual             structured
# 175                         47.0         collaborative               flexible
# ...                          ...                   ...                    ...
# 7059                        66.0            individual             structured
# 7061                        15.0            individual             structured
# 7071                        26.0         collaborative             structured
# 7077                        92.0         collaborative               flexible
# 7093                        26.0         collaborative             structured
#
#       risk_tolerance              career_cluster
# 4                2.0  Healthcare & Life Sciences
# 13               2.0     Design & Creative Media
# 37               1.0    Technology & Engineering
# 95               1.0    Technology & Engineering
# 175              0.0  Healthcare & Life Sciences
# ...              ...                         ...
# 7059             1.0       Business & Management
# 7061             0.0         Finance & Economics
# 7071             1.0     Design & Creative Media
# 7077             2.0    Technology & Engineering
# 7093             2.0  Healthcare & Life Sciences
#
# [140 rows x 24 columns]
#        age education_level field_of_study  experience_years  openness  \
# 26    22.0     High School        Biology                 1       3.0
# 61    26.0     High School        Biology                 2       4.0
# 144   23.0   Undergraduate    Engineering                 2       4.0
# 169   22.0        Graduate         Design                 2       4.0
# 189   24.0     High School       Business                 1       4.0
# ...    ...             ...            ...               ...       ...
# 7081  20.0        Graduate          Other                 5       4.0
# 7083  19.0   Undergraduate          Other                 1       4.0
# 7087  21.0        Graduate          Other                 3       5.0
# 7094  27.0        Graduate          Other                 0       2.0
# 7098  25.0     High School          Other                 5       2.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 26                  1.0           1.0            5.0          4.0
# 61                  1.0           5.0            3.0          4.0
# 144                 1.0           2.0            4.0          4.0
# 169                 1.0           4.0            3.0          3.0
# 189                 1.0           3.0            4.0          2.0
# ...                 ...           ...            ...          ...
# 7081                1.0           2.0            1.0          2.0
# 7083                1.0           3.0            3.0          1.0
# 7087                1.0           4.0            5.0          3.0
# 7094                1.0           4.0            3.0          4.0
# 7098                1.0           5.0            2.0          4.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 26                2.0  ...                      2.0                 35.0
# 61                1.0  ...                      2.0                 47.0
# 144               2.0  ...                      2.0                 58.0
# 169               3.0  ...                      4.0                 31.0
# 189               4.0  ...                      2.0                 38.0
# ...               ...  ...                      ...                  ...
# 7081              3.0  ...                      5.0                 24.0
# 7083              5.0  ...                      2.0                 51.0
# 7087              3.0  ...                      4.0                 14.0
# 7094              2.0  ...                      5.0                 65.0
# 7098              4.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 26                 63.0               42.0                    28.0
# 61                 88.0               44.0                    42.0
# 144                58.0               32.0                    53.0
# 169                39.0               37.0                    21.0
# 189                53.0               37.0                    20.0
# ...                 ...                ...                     ...
# 7081               91.0               62.0                    52.0
# 7083               70.0               33.0                    20.0
# 7087               93.0               12.0                    25.0
# 7094               99.0               98.0                    12.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 26                          23.0         collaborative             structured
# 61                          50.0         collaborative               flexible
# 144                         64.0            individual               flexible
# 169                         39.0         collaborative               flexible
# 189                         37.0         collaborative               flexible
# ...                          ...                   ...                    ...
# 7081                        52.0         collaborative             structured
# 7083                        30.0            individual             structured
# 7087                        61.0         collaborative               flexible
# 7094                        95.0            individual             structured
# 7098                        78.0            individual             structured
#
#       risk_tolerance                career_cluster
# 26               0.0         Business & Management
# 61               2.0         Business & Management
# 144              1.0  Entrepreneurship & Freelance
# 169              2.0    Healthcare & Life Sciences
# 189              0.0    Healthcare & Life Sciences
# ...              ...                           ...
# 7081             2.0  Entrepreneurship & Freelance
# 7083             1.0     Education & Social Impact
# 7087             1.0         Business & Management
# 7094             2.0         Business & Management
# 7098             0.0      Technology & Engineering
#
# [122 rows x 24 columns]
#        age education_level field_of_study  experience_years  openness  \
# 12    21.0        Graduate       Business                 1       3.0
# 56    27.0     High School    Engineering                 1       5.0
# 61    26.0     High School        Biology                 2       4.0
# 79    22.0   Undergraduate      Economics                 1       2.0
# 123   22.0        Graduate    Engineering                 2       3.0
# ...    ...             ...            ...               ...       ...
# 7091  24.0        Graduate          Other                 3       5.0
# 7093  18.0   Undergraduate          Other                 2       1.0
# 7096  29.0   Undergraduate          Other                 2       4.0
# 7097  25.0     High School          Other                 1       5.0
# 7098  25.0     High School          Other                 5       2.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 12                  4.0           5.0            2.0          3.0
# 56                  4.0           5.0            3.0          4.0
# 61                  1.0           5.0            3.0          4.0
# 79                  2.0           5.0            2.0          2.0
# 123                 3.0           5.0            3.0          2.0
# ...                 ...           ...            ...          ...
# 7091                3.0           5.0            5.0          1.0
# 7093                4.0           5.0            3.0          1.0
# 7096                3.0           5.0            3.0          3.0
# 7097                3.0           5.0            3.0          2.0
# 7098                1.0           5.0            2.0          4.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 12                1.0  ...                      2.0                 66.0
# 56                4.0  ...                      3.0                 74.0
# 61                1.0  ...                      2.0                 47.0
# 79                1.0  ...                      2.0                 42.0
# 123               1.0  ...                      4.0                 28.0
# ...               ...  ...                      ...                  ...
# 7091              2.0  ...                      5.0                 51.0
# 7093              5.0  ...                      2.0                 97.0
# 7096              1.0  ...                      3.0                 23.0
# 7097              1.0  ...                      1.0                 90.0
# 7098              4.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 12                 57.0               57.0                    40.0
# 56                 52.0               56.0                    65.0
# 61                 88.0               44.0                    42.0
# 79                 42.0               51.0                    47.0
# 123                21.0               95.0                    29.0
# ...                 ...                ...                     ...
# 7091               23.0               30.0                    82.0
# 7093               11.0               79.0                    66.0
# 7096               42.0               10.0                    41.0
# 7097               72.0               33.0                    86.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 12                          35.0         collaborative             structured
# 56                          46.0         collaborative             structured
# 61                          50.0         collaborative               flexible
# 79                          56.0            individual               flexible
# 123                         56.0         collaborative             structured
# ...                          ...                   ...                    ...
# 7091                        70.0         collaborative             structured
# 7093                        26.0         collaborative             structured
# 7096                        96.0            individual               flexible
# 7097                        34.0            individual             structured
# 7098                        78.0            individual             structured
#
#       risk_tolerance                career_cluster
# 12               1.0  Entrepreneurship & Freelance
# 56               2.0      Technology & Engineering
# 61               2.0         Business & Management
# 79               0.0    Healthcare & Life Sciences
# 123              2.0       Design & Creative Media
# ...              ...                           ...
# 7091             0.0      Technology & Engineering
# 7093             2.0    Healthcare & Life Sciences
# 7096             1.0           Finance & Economics
# 7097             1.0     Education & Social Impact
# 7098             0.0      Technology & Engineering
#
# [133 rows x 24 columns]
#        age education_level field_of_study  experience_years  openness  \
# 37    23.0     High School             IT                 3       1.0
# 54    26.0        Graduate       Business                 1       3.0
# 75    20.0        Graduate      Economics                 0       4.0
# 206   25.0     High School        Biology                 2       2.0
# 230   25.0        Graduate        Biology                 3       4.0
# ...    ...             ...            ...               ...       ...
# 7069  30.0   Undergraduate          Other                 5       5.0
# 7076  26.0        Graduate          Other                 1       2.0
# 7081  20.0        Graduate          Other                 5       4.0
# 7082  23.0   Undergraduate          Other                 2       3.0
# 7086  26.0   Undergraduate          Other                 1       3.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 37                  5.0           4.0            1.0          2.0
# 54                  2.0           2.0            1.0          1.0
# 75                  4.0           2.0            1.0          2.0
# 206                 2.0           3.0            1.0          4.0
# 230                 4.0           1.0            1.0          3.0
# ...                 ...           ...            ...          ...
# 7069                1.0           3.0            1.0          3.0
# 7076                3.0           4.0            1.0          5.0
# 7081                1.0           2.0            1.0          2.0
# 7082                2.0           1.0            1.0          2.0
# 7086                5.0           5.0            1.0          5.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 37                3.0  ...                      3.0                 92.0
# 54                2.0  ...                      2.0                 23.0
# 75                2.0  ...                      3.0                 30.0
# 206               3.0  ...                      3.0                 97.0
# 230               1.0  ...                      3.0                 32.0
# ...               ...  ...                      ...                  ...
# 7069              1.0  ...                      5.0                 24.0
# 7076              3.0  ...                      1.0                 72.0
# 7081              3.0  ...                      5.0                 24.0
# 7082              4.0  ...                      3.0                 38.0
# 7086              2.0  ...                      5.0                 97.0
#
#       interest_business  interest_creative  interest_health_social  \
# 37                 47.0               23.0                    32.0
# 54                 55.0               93.0                    36.0
# 75                 56.0               33.0                    39.0
# 206                23.0               17.0                    30.0
# 230                54.0               32.0                    47.0
# ...                 ...                ...                     ...
# 7069               47.0               15.0                    79.0
# 7076               51.0               13.0                    72.0
# 7081               91.0               62.0                    52.0
# 7082               95.0               62.0                    32.0
# 7086               82.0               48.0                    77.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 37                          52.0            individual               flexible
# 54                          45.0            individual               flexible
# 75                          31.0            individual               flexible
# 206                         53.0         collaborative             structured
# 230                         37.0         collaborative               flexible
# ...                          ...                   ...                    ...
# 7069                        89.0            individual               flexible
# 7076                        74.0            individual               flexible
# 7081                        52.0         collaborative             structured
# 7082                        83.0         collaborative               flexible
# 7086                        10.0            individual             structured
#
#       risk_tolerance                career_cluster
# 37               1.0      Technology & Engineering
# 54               2.0       Design & Creative Media
# 75               1.0    Healthcare & Life Sciences
# 206              0.0      Technology & Engineering
# 230              2.0    Healthcare & Life Sciences
# ...              ...                           ...
# 7069             1.0     Education & Social Impact
# 7076             1.0     Education & Social Impact
# 7081             2.0  Entrepreneurship & Freelance
# 7082             0.0           Finance & Economics
# 7086             0.0    Healthcare & Life Sciences
#
# [132 rows x 24 columns]
#        age education_level    field_of_study  experience_years  openness  \
# 23    24.0   Undergraduate            Design                 1       5.0
# 36    23.0        Graduate           Biology                 2       5.0
# 42    25.0     High School            Design                 2       3.0
# 77    27.0        Graduate       Engineering                 3       4.0
# 177   20.0        Graduate  Computer Science                 2       4.0
# ...    ...             ...               ...               ...       ...
# 7072  29.0     High School             Other                 3       5.0
# 7076  26.0        Graduate             Other                 1       2.0
# 7085  30.0        Graduate             Other                 5       5.0
# 7086  26.0   Undergraduate             Other                 1       3.0
# 7092  29.0   Undergraduate             Other                 6       4.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 23                  4.0           4.0            4.0          5.0
# 36                  5.0           2.0            2.0          5.0
# 42                  4.0           2.0            4.0          5.0
# 77                  3.0           3.0            3.0          5.0
# 177                 5.0           2.0            4.0          5.0
# ...                 ...           ...            ...          ...
# 7072                3.0           4.0            2.0          5.0
# 7076                3.0           4.0            1.0          5.0
# 7085                2.0           2.0            4.0          5.0
# 7086                5.0           5.0            1.0          5.0
# 7092                5.0           4.0            2.0          5.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 23                3.0  ...                      2.0                 46.0
# 36                3.0  ...                      2.0                 39.0
# 42                2.0  ...                      2.0                 73.0
# 77                2.0  ...                      4.0                 33.0
# 177               3.0  ...                      2.0                 84.0
# ...               ...  ...                      ...                  ...
# 7072              2.0  ...                      5.0                 61.0
# 7076              3.0  ...                      1.0                 72.0
# 7085              1.0  ...                      2.0                 25.0
# 7086              2.0  ...                      5.0                 97.0
# 7092              5.0  ...                      2.0                 55.0
#
#       interest_business  interest_creative  interest_health_social  \
# 23                 55.0               17.0                    22.0
# 36                 79.0               34.0                    29.0
# 42                 82.0               24.0                    49.0
# 77                 34.0               40.0                    57.0
# 177                41.0               39.0                    43.0
# ...                 ...                ...                     ...
# 7072               64.0               41.0                    53.0
# 7076               51.0               13.0                    72.0
# 7085               46.0               95.0                    33.0
# 7086               82.0               48.0                    77.0
# 7092               83.0               99.0                    43.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 23                          14.0         collaborative               flexible
# 36                          46.0            individual               flexible
# 42                          59.0            individual               flexible
# 77                          55.0         collaborative               flexible
# 177                         64.0         collaborative             structured
# ...                          ...                   ...                    ...
# 7072                        69.0         collaborative             structured
# 7076                        74.0            individual               flexible
# 7085                        49.0         collaborative             structured
# 7086                        10.0            individual             structured
# 7092                        80.0         collaborative               flexible
#
#       risk_tolerance              career_cluster
# 23               0.0  Healthcare & Life Sciences
# 36               2.0       Business & Management
# 42               2.0         Finance & Economics
# 77               2.0  Healthcare & Life Sciences
# 177              2.0    Technology & Engineering
# ...              ...                         ...
# 7072             0.0  Healthcare & Life Sciences
# 7076             1.0   Education & Social Impact
# 7085             1.0     Design & Creative Media
# 7086             0.0  Healthcare & Life Sciences
# 7092             2.0     Design & Creative Media
#
# [111 rows x 24 columns]
#        age education_level    field_of_study  experience_years  openness  \
# 4     23.0        Graduate                IT                 3       1.0
# 25    23.0   Undergraduate         Economics                 2       3.0
# 32    24.0     High School            Design                 2       2.0
# 39    21.0     High School         Economics                 0       2.0
# 87    24.0        Graduate  Computer Science                 2       2.0
# ...    ...             ...               ...               ...       ...
# 7083  19.0   Undergraduate             Other                 1       4.0
# 7088  27.0     High School             Other                 2       3.0
# 7092  29.0   Undergraduate             Other                 6       4.0
# 7093  18.0   Undergraduate             Other                 2       1.0
# 7095  25.0        Graduate             Other                 3       3.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 4                   4.0           3.0            3.0          3.0
# 25                  4.0           2.0            3.0          2.0
# 32                  5.0           3.0            3.0          3.0
# 39                  4.0           1.0            5.0          1.0
# 87                  3.0           3.0            2.0          3.0
# ...                 ...           ...            ...          ...
# 7083                1.0           3.0            3.0          1.0
# 7088                3.0           4.0            2.0          3.0
# 7092                5.0           4.0            2.0          5.0
# 7093                4.0           5.0            3.0          1.0
# 7095                2.0           4.0            5.0          3.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 4                 0.0  ...                      2.0                 34.0
# 25                0.0  ...                      2.0                 37.0
# 32                5.0  ...                      3.0                 71.0
# 39                5.0  ...                      2.0                 91.0
# 87                0.0  ...                      2.0                 31.0
# ...               ...  ...                      ...                  ...
# 7083              5.0  ...                      2.0                 51.0
# 7088              5.0  ...                      4.0                 20.0
# 7092              5.0  ...                      2.0                 55.0
# 7093              5.0  ...                      2.0                 97.0
# 7095              5.0  ...                      2.0                 36.0
#
#       interest_business  interest_creative  interest_health_social  \
# 4                  54.0               38.0                    32.0
# 25                 48.0               42.0                    49.0
# 32                 40.0               30.0                    47.0
# 39                 41.0               36.0                    34.0
# 87                 47.0               46.0                    24.0
# ...                 ...                ...                     ...
# 7083               70.0               33.0                    20.0
# 7088               39.0               62.0                    36.0
# 7092               83.0               99.0                    43.0
# 7093               11.0               79.0                    66.0
# 7095               40.0               76.0                    43.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 4                           52.0         collaborative             structured
# 25                          56.0            individual             structured
# 32                          50.0            individual             structured
# 39                          44.0            individual               flexible
# 87                          45.0         collaborative               flexible
# ...                          ...                   ...                    ...
# 7083                        30.0            individual             structured
# 7088                        23.0            individual             structured
# 7092                        80.0         collaborative               flexible
# 7093                        26.0         collaborative             structured
# 7095                        33.0         collaborative               flexible
#
#       risk_tolerance                career_cluster
# 4                2.0    Healthcare & Life Sciences
# 25               0.0     Education & Social Impact
# 32               1.0      Technology & Engineering
# 39               0.0      Technology & Engineering
# 87               1.0    Healthcare & Life Sciences
# ...              ...                           ...
# 7083             1.0     Education & Social Impact
# 7088             1.0  Entrepreneurship & Freelance
# 7092             2.0       Design & Creative Media
# 7093             2.0    Healthcare & Life Sciences
# 7095             2.0  Entrepreneurship & Freelance
#
# [569 rows x 24 columns]
# Empty DataFrame
# Columns: [age, education_level, field_of_study, experience_years, openness, conscientiousness, extraversion, agreeableness, neuroticism, technical_skill, data_reasoning_skill, communication_skill, problem_solving_skill, leadership_skill, creative_thinking_skill, interest_technology, interest_business, interest_creative, interest_health_social, interest_research_academic, preferred_work_style, preferred_environment, risk_tolerance, career_cluster]
# Index: []
#
# [0 rows x 24 columns]
# Empty DataFrame
# Columns: [age, education_level, field_of_study, experience_years, openness, conscientiousness, extraversion, agreeableness, neuroticism, technical_skill, data_reasoning_skill, communication_skill, problem_solving_skill, leadership_skill, creative_thinking_skill, interest_technology, interest_business, interest_creative, interest_health_social, interest_research_academic, preferred_work_style, preferred_environment, risk_tolerance, career_cluster]
# Index: []
#
# [0 rows x 24 columns]
#        age education_level    field_of_study  experience_years  openness  \
# 14    30.0   Undergraduate  Computer Science                 3       2.0
# 88    25.0   Undergraduate                IT                 2       4.0
# 159   20.0   Undergraduate                IT                 2       4.0
# 222   18.0     High School         Economics                 0       5.0
# 266   18.0        Graduate           Biology                 0       3.0
# ...    ...             ...               ...               ...       ...
# 7056  27.0     High School             Other                 3       5.0
# 7062  19.0   Undergraduate             Other                 3       4.0
# 7063  27.0     High School             Other                 0       2.0
# 7065  24.0        Graduate             Other                 3       5.0
# 7068  27.0   Undergraduate             Other                 4       2.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 14                  3.0           4.0            3.0          3.0
# 88                  3.0           2.0            4.0          1.0
# 159                 3.0           2.0            3.0          3.0
# 222                 4.0           2.0            3.0          3.0
# 266                 3.0           2.0            4.0          2.0
# ...                 ...           ...            ...          ...
# 7056                2.0           5.0            1.0          5.0
# 7062                4.0           5.0            4.0          4.0
# 7063                3.0           2.0            2.0          3.0
# 7065                1.0           4.0            3.0          3.0
# 7068                1.0           4.0            1.0          3.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 14                3.0  ...                      2.0                 42.0
# 88                0.0  ...                      3.0                 55.0
# 159               4.0  ...                      2.0                 50.0
# 222               2.0  ...                      2.0                 41.0
# 266               0.0  ...                      3.0                 39.0
# ...               ...  ...                      ...                  ...
# 7056              3.0  ...                      4.0                 59.0
# 7062              3.0  ...                      4.0                 19.0
# 7063              3.0  ...                      4.0                 27.0
# 7065              2.0  ...                      1.0                 72.0
# 7068              1.0  ...                      4.0                 61.0
#
#       interest_business  interest_creative  interest_health_social  \
# 14                 91.0               15.0                    33.0
# 88                 40.0               77.0                    37.0
# 159                55.0               48.0                    44.0
# 222                40.0               70.0                    25.0
# 266                31.0               27.0                    36.0
# ...                 ...                ...                     ...
# 7056               92.0               18.0                    67.0
# 7062               41.0               91.0                    91.0
# 7063               21.0               53.0                    73.0
# 7065               70.0               29.0                    49.0
# 7068               72.0               71.0                    83.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 14                          46.0         collaborative             structured
# 88                          65.0            individual               flexible
# 159                         42.0         collaborative               flexible
# 222                         47.0         collaborative             structured
# 266                         21.0            individual               flexible
# ...                          ...                   ...                    ...
# 7056                        96.0         collaborative             structured
# 7062                        80.0         collaborative               flexible
# 7063                        95.0            individual               flexible
# 7065                        49.0            individual             structured
# 7068                        25.0         collaborative               flexible
#
#       risk_tolerance                career_cluster
# 14               2.0           Finance & Economics
# 88               1.0       Design & Creative Media
# 159              2.0  Entrepreneurship & Freelance
# 222              0.0       Design & Creative Media
# 266              2.0    Healthcare & Life Sciences
# ...              ...                           ...
# 7056             0.0      Technology & Engineering
# 7062             0.0     Education & Social Impact
# 7063             0.0      Technology & Engineering
# 7065             0.0    Healthcare & Life Sciences
# 7068             1.0           Finance & Economics
#
# [126 rows x 24 columns]
#        age education_level    field_of_study  experience_years  openness  \
# 11    24.0   Undergraduate            Design                 0       4.0
# 71    24.0     High School          Business                 1       4.0
# 91    30.0        Graduate  Computer Science                 0       4.0
# 141   20.0   Undergraduate        Psychology                 2       3.0
# 155   25.0   Undergraduate        Psychology                 1       3.0
# ...    ...             ...               ...               ...       ...
# 7066  21.0     High School             Other                 4       2.0
# 7078  19.0        Graduate             Other                 6       4.0
# 7084  26.0        Graduate             Other                 2       4.0
# 7093  18.0   Undergraduate             Other                 2       1.0
# 7094  27.0        Graduate             Other                 0       2.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# ...
# 28               1.0     Design & Creative Media
# 50               2.0     Design & Creative Media
# 54               2.0     Design & Creative Media
# ...              ...                         ...
# 7077             2.0    Technology & Engineering
# 7079             2.0  Healthcare & Life Sciences
# 7085             1.0     Design & Creative Media
# 7092             2.0     Design & Creative Media
# 7094             2.0       Business & Management
#
# [524 rows x 24 columns]
#        age education_level    field_of_study  experience_years  openness  \
# 629   24.0     High School       Engineering                 3       4.0
# 636   26.0   Undergraduate       Engineering                 0       3.0
# 3073  28.0     High School  Computer Science                 0       3.0
# 3715  28.0        Graduate                IT                 1       4.0
# 5026  22.0     High School                IT                 4       5.0
# ...    ...             ...               ...               ...       ...
# 7052  24.0     High School             Other                 1       1.0
# 7057  20.0     High School             Other                 1       3.0
# 7059  26.0        Graduate             Other                 2       1.0
# 7062  19.0   Undergraduate             Other                 3       4.0
# 7098  25.0     High School             Other                 5       2.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 629                 4.0           3.0            4.0          2.0
# 636                 3.0           1.0            2.0          5.0
# 3073                4.0           3.0            2.0          4.0
# 3715                2.0           3.0            4.0          3.0
# 5026                3.0           2.0            5.0          3.0
# ...                 ...           ...            ...          ...
# 7052                1.0           3.0            4.0          1.0
# 7057                5.0           5.0            5.0          3.0
# 7059                4.0           3.0            4.0          1.0
# 7062                4.0           5.0            4.0          4.0
# 7098                1.0           5.0            2.0          4.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 629               2.0  ...                      1.0                 45.0
# 636               3.0  ...                      3.0                 49.0
# 3073              4.0  ...                      3.0                 40.0
# 3715              3.0  ...                      4.0                 36.0
# 5026              2.0  ...                      2.0                 28.0
# ...               ...  ...                      ...                  ...
# 7052              1.0  ...                      4.0                 52.0
# 7057              4.0  ...                      5.0                 82.0
# 7059              3.0  ...                      5.0                 69.0
# 7062              3.0  ...                      4.0                 19.0
# 7098              4.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 629                77.0               22.0                    90.0
# 636                74.0               24.0                    89.0
# 3073               86.0               43.0                    88.0
# 3715               52.0               41.0                    91.0
# 5026               22.0               18.0                    98.0
# ...                 ...                ...                     ...
# 7052               90.0              100.0                    94.0
# 7057               60.0               17.0                    94.0
# 7059               32.0               24.0                    89.0
# 7062               41.0               91.0                    91.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 629                         52.0            individual             structured
# 636                         42.0         collaborative             structured
# 3073                        46.0         collaborative               flexible
# 3715                        38.0         collaborative             structured
# 5026                        78.0         collaborative             structured
# ...                          ...                   ...                    ...
# 7052                        74.0         collaborative             structured
# 7057                        19.0            individual               flexible
# 7059                        66.0            individual             structured
# 7062                        80.0         collaborative               flexible
# 7098                        78.0            individual             structured
#
#       risk_tolerance              career_cluster
# 629              1.0         Finance & Economics
# 636              2.0       Business & Management
# 3073             0.0       Business & Management
# 3715             2.0       Business & Management
# 5026             2.0  Healthcare & Life Sciences
# ...              ...                         ...
# 7052             1.0       Business & Management
# 7057             1.0     Design & Creative Media
# 7059             1.0       Business & Management
# 7062             0.0   Education & Social Impact
# 7098             0.0    Technology & Engineering
#
# [126 rows x 24 columns]
#        age education_level    field_of_study  experience_years  openness  \
# 58    23.0     High School            Design                 2       4.0
# 1076  23.0        Graduate  Computer Science                 0       4.0
# 1940  20.0        Graduate         Economics                 1       2.0
# 2195  29.0   Undergraduate         Economics                 1       2.0
# 2374  18.0   Undergraduate          Business                 0       4.0
# 2616  26.0   Undergraduate           Biology                 1       3.0
# 3072  23.0   Undergraduate            Design                 1       4.0
# 3077  26.0        Graduate           Biology                 0       3.0
# 3222  24.0   Undergraduate       Engineering                 1       2.0
# 3319  25.0   Undergraduate           Biology                 2       4.0
# 3543  18.0   Undergraduate            Design                 0       4.0
# 3906  18.0        Graduate          Business                 0       4.0
# 4527  26.0        Graduate                IT                 1       4.0
# 4660  15.0        Graduate            Design                 0       5.0
# 7044  25.0        Graduate             Other                 6       4.0
# 7056  27.0     High School             Other                 3       5.0
# 7058  23.0   Undergraduate             Other                 3       4.0
# 7063  27.0     High School             Other                 0       2.0
# 7074  26.0   Undergraduate             Other                 1       4.0
# 7094  27.0        Graduate             Other                 0       2.0
# 7096  29.0   Undergraduate             Other                 2       4.0
#
#       conscientiousness  extraversion  agreeableness  neuroticism  \
# 58                  2.0           4.0            5.0          2.0
# 1076                4.0           3.0            3.0          2.0
# 1940                3.0           2.0            1.0          4.0
# 2195                4.0           3.0            3.0          2.0
# 2374                4.0           3.0            4.0          2.0
# 2616                2.0           3.0            4.0          2.0
# 3072                4.0           4.0            4.0          2.0
# 3077                4.0           1.0            4.0          2.0
# 3222                4.0           3.0            4.0          5.0
# 3319                5.0           3.0            3.0          2.0
# 3543                4.0           4.0            3.0          3.0
# 3906                4.0           1.0            2.0          4.0
# 4527                4.0           4.0            3.0          2.0
# 4660                1.0           3.0            3.0          1.0
# 7044                4.0           2.0            4.0          1.0
# 7056                2.0           5.0            1.0          5.0
# 7058                1.0           3.0            4.0          3.0
# 7063                3.0           2.0            2.0          3.0
# 7074                1.0           3.0            2.0          1.0
# 7094                1.0           4.0            3.0          4.0
# 7096                3.0           5.0            3.0          3.0
#
#       technical_skill  ...  creative_thinking_skill  interest_technology  \
# 58                3.0  ...                      2.0                 56.0
# 1076              2.0  ...                      4.0                 40.0
# 1940              0.0  ...                      0.0                 50.0
# 2195              1.0  ...                      3.0                 87.0
# 2374              1.0  ...                      2.0                 46.0
# 2616              2.0  ...                      1.0                 50.0
# 3072              1.0  ...                      2.0                 14.0
# 3077              2.0  ...                      3.0                 24.0
# 3222              1.0  ...                      4.0                 30.0
# 3319              1.0  ...                      2.0                 33.0
# 3543              3.0  ...                      4.0                 74.0
# 3906              4.0  ...                      1.0                 55.0
# 4527              2.0  ...                      1.0                 48.0
# 4660              1.0  ...                      2.0                 58.0
# 7044              2.0  ...                      4.0                 17.0
# 7056              3.0  ...                      4.0                 59.0
# 7058              3.0  ...                      1.0                 15.0
# 7063              3.0  ...                      4.0                 27.0
# 7074              3.0  ...                      1.0                 41.0
# 7094              2.0  ...                      5.0                 65.0
# 7096              1.0  ...                      3.0                 23.0
#
#       interest_business  interest_creative  interest_health_social  \
# 58                 85.0               36.0                    51.0
# 1076               43.0               44.0                    54.0
# 1940               32.0               38.0                    46.0
# 2195               47.0               35.0                    40.0
# 2374               41.0               41.0                     9.0
# 2616               77.0               60.0                    34.0
# 3072               28.0               75.0                    25.0
# 3077               76.0               43.0                    38.0
# 3222               76.0               54.0                    27.0
# 3319               54.0               22.0                    29.0
# 3543               62.0               24.0                    26.0
# 3906               70.0               39.0                    13.0
# 4527               52.0               39.0                    36.0
# 4660               77.0                8.0                    64.0
# 7044               72.0               63.0                     6.0
# 7056               92.0               18.0                    67.0
# 7058               16.0               60.0                    17.0
# 7063               21.0               53.0                    73.0
# 7074               65.0               94.0                    22.0
# 7094               99.0               98.0                    12.0
# 7096               42.0               10.0                    41.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 58                           2.0            individual               flexible
# 1076                         1.0            individual               flexible
# 1940                         0.0         collaborative             structured
# 2195                         1.0         collaborative               flexible
# 2374                         0.0         collaborative               flexible
# 2616                         1.0            individual               flexible
# 3072                         2.0            individual               flexible
# 3077                         0.0         collaborative             structured
# 3222                         1.0            individual             structured
# 3319                         0.0            individual             structured
# 3543                        97.0            individual             structured
# 3906                         2.0            individual               flexible
# 4527                         0.0            individual             structured
# 4660                         0.0            individual             structured
# 7044                        97.0            individual               flexible
# 7056                        96.0         collaborative             structured
# 7058                       100.0         collaborative             structured
# 7063                        95.0            individual               flexible
# 7074                        95.0         collaborative               flexible
# 7094                        95.0            individual             structured
# 7096                        96.0            individual               flexible
#
#       risk_tolerance                career_cluster
# 58               0.0         Business & Management
# 1076             0.0    Healthcare & Life Sciences
# 1940             2.0    Healthcare & Life Sciences
# 2195             1.0      Technology & Engineering
# 2374             0.0    Healthcare & Life Sciences
# 2616             0.0  Entrepreneurship & Freelance
# 3072             0.0       Design & Creative Media
# 3077             2.0         Business & Management
# 3222             0.0         Business & Management
# 3319             2.0    Healthcare & Life Sciences
# 3543             2.0           Finance & Economics
# 3906             1.0         Business & Management
# 4527             2.0     Education & Social Impact
# 4660             0.0         Business & Management
# 7044             2.0    Healthcare & Life Sciences
# 7056             0.0      Technology & Engineering
# 7058             2.0    Healthcare & Life Sciences
# 7063             0.0      Technology & Engineering
# 7074             2.0  Entrepreneurship & Freelance
# 7094             2.0         Business & Management
# 7096             1.0           Finance & Economics
#
# [21 rows x 24 columns]
# Empty DataFrame
# Columns: [age, education_level, field_of_study, experience_years, openness, conscientiousness, extraversion, agreeableness, neuroticism, technical_skill, data_reasoning_skill, communication_skill, problem_solving_skill, leadership_skill, creative_thinking_skill, interest_technology, interest_business, interest_creative, interest_health_social, interest_research_academic, preferred_work_style, preferred_environment, risk_tolerance, career_cluster]
# Index: []
#
# [0 rows x 24 columns]
# {'age': 68,
#  'experience_years': 710,
#  'openness': 140,
#  'conscientiousness': 122,
#  'extraversion': 133,
#  'agreeableness': 132,
#  'neuroticism': 111,
#  'technical_skill': 569,
#  'data_reasoning_skill': 0,
#  'communication_skill': 0,
#  'problem_solving_skill': 126,
#  'leadership_skill': 250,
#  'creative_thinking_skill': 249,
#  'interest_technology': 44,
#  'interest_business': 0,
#  'interest_creative': 524,
#  'interest_health_social': 126,
#  'interest_research_academic': 21,
#  'risk_tolerance': 0}

# %%
plt.boxplot(df['age'])
plt.title('Age Outliers')
plt.show()

# %%
plt.boxplot(df['experience_years'])
plt.title('Experience Years Outliers')
plt.show()

# %%
#Cap experience years to be logically consistent with age
df['experience_years'] = np.minimum(df['experience_years'],df['age'] - 18)
df['experience_years'] = df['experience_years'].clip(lower=0)

# %%
#Visualization
df1=df['career_cluster'].value_counts().sort_values(ascending=False)
print(df1)
plt.barh(df1.index,df1.values)
plt.xlabel('Career Cluster')
plt.ylabel('Count')
plt.title('Distribution of Career Clusters')
plt.show()
# Out:
# career_cluster
# Education & Social Impact       1081
# Technology & Engineering        1038
# Design & Creative Media         1032
# Healthcare & Life Sciences      1013
# Business & Management            999
# Entrepreneurship & Freelance     995
# Finance & Economics              941
# Name: count, dtype: int64

# %%
personality_cols = ['openness', 'conscientiousness', 'extraversion','agreeableness', 'neuroticism']
personality_mean = df.groupby('career_cluster')[personality_cols].mean().mean(axis=1)
plt.figure(figsize=(9,5))
plt.plot(personality_mean.index, personality_mean.values, marker='o')
plt.xlabel("Career Cluster")
plt.ylabel("Average Personality Score")
plt.title("Average Personality Profile across Career Clusters")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
skill_cols = [ 'technical_skill', 'data_reasoning_skill', 'communication_skill','problem_solving_skill', 'leadership_skill', 'creative_thinking_skill']
skill_mean = df.groupby('career_cluster')[skill_cols].mean().mean(axis=1)
plt.figure(figsize=(9,5))
plt.bar(skill_mean.index, skill_mean.values, color='teal')
plt.xlabel("Career Cluster")
plt.ylabel("Average Skill Level")
plt.title("Average Skill Level across Career Clusters")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
interest_cols = ['interest_technology', 'interest_business','interest_creative', 
                 'interest_health_social','interest_research_academic']
interest_mean = df.groupby('career_cluster')[interest_cols].mean().mean(axis=1)
plt.figure(figsize=(9,5))
plt.plot(interest_mean.index, interest_mean.values, marker='o', color='purple')
plt.xlabel("Career Cluster")
plt.ylabel("Average Interest Level")
plt.title("Average Interest Level across Career Clusters")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Correlation
num_cols = df.select_dtypes(include=['int64','float64']).columns
corr = df[num_cols].corr()
corr
# Out:
#                                  age  experience_years  openness  \
# age                         1.000000          0.311173 -0.021848
# experience_years            0.311173          1.000000  0.059893
# openness                   -0.021848          0.059893  1.000000
# conscientiousness          -0.022669          0.060711  0.068086
# extraversion               -0.013968          0.094651  0.050813
# agreeableness              -0.016703          0.056437  0.065517
# neuroticism                 0.031736         -0.060455 -0.047694
# technical_skill            -0.029204          0.085728  0.048939
# data_reasoning_skill       -0.037814          0.161141  0.110082
# communication_skill        -0.027393          0.168887  0.122922
# problem_solving_skill      -0.006356         -0.006760  0.001885
# leadership_skill           -0.000271          0.089940  0.044671
# creative_thinking_skill    -0.002938          0.064499  0.053043
# interest_technology        -0.001837          0.000778 -0.021861
# interest_business           0.022271         -0.037413 -0.039331
# interest_creative           0.012513         -0.023057 -0.032376
# interest_health_social      0.005148          0.001227 -0.006859
# interest_research_academic -0.030942          0.061394  0.074745
# risk_tolerance             -0.000849          0.008057  0.001764
#
#                             conscientiousness  extraversion  agreeableness  \
# age                                 -0.022669     -0.013968      -0.016703
# experience_years                     0.060711      0.094651       0.056437
# openness                             0.068086      0.050813       0.065517
# conscientiousness                    1.000000      0.067943       0.069318
# extraversion                         0.067943      1.000000       0.052872
# agreeableness                        0.069318      0.052872       1.000000
# neuroticism                         -0.056983     -0.047618      -0.082183
# technical_skill                      0.055440      0.056944       0.071396
# data_reasoning_skill                 0.109482      0.117566       0.107203
# communication_skill                  0.135066      0.132071       0.129009
# problem_solving_skill                0.016186     -0.010032       0.019888
# leadership_skill                     0.048132      0.048842       0.068887
# creative_thinking_skill              0.045457      0.043581       0.042491
# interest_technology                 -0.026336      0.017874       0.001949
# interest_business                   -0.035733     -0.053437      -0.017088
# interest_creative                   -0.034089     -0.024869      -0.033996
# interest_health_social              -0.001525      0.019669      -0.005418
# interest_research_academic           0.049581      0.063608       0.070478
# risk_tolerance                      -0.003470     -0.012575      -0.007328
#
#                             neuroticism  technical_skill  \
# age                            0.031736        -0.029204
# experience_years              -0.060455         0.085728
# openness                      -0.047694         0.048939
# conscientiousness             -0.056983         0.055440
# extraversion                  -0.047618         0.056944
# agreeableness                 -0.082183         0.071396
# neuroticism                    1.000000        -0.046481
# technical_skill               -0.046481         1.000000
# data_reasoning_skill          -0.123666         0.437928
# communication_skill           -0.117951         0.146461
# problem_solving_skill         -0.020832         0.081502
# leadership_skill              -0.051534         0.052190
# creative_thinking_skill       -0.028540         0.051788
# interest_technology           -0.007567         0.500980
# interest_business              0.054146         0.118159
# interest_creative              0.030094        -0.216339
# interest_health_social         0.013251        -0.157306
# interest_research_academic    -0.076756         0.061916
# risk_tolerance                 0.008726         0.014422
#
#                             data_reasoning_skill  communication_skill  \
# age                                    -0.037814            -0.027393
# experience_years                        0.161141             0.168887
# openness                                0.110082             0.122922
# conscientiousness                       0.109482             0.135066
# extraversion                            0.117566             0.132071
# agreeableness                           0.107203             0.129009
# neuroticism                            -0.123666            -0.117951
# technical_skill                         0.437928             0.146461
# data_reasoning_skill                    1.000000             0.289573
# communication_skill                     0.289573             1.000000
# problem_solving_skill                   0.066898             0.024926
# leadership_skill                        0.106241             0.106585
# creative_thinking_skill                 0.106068             0.114804
# interest_technology                     0.363057            -0.008657
# interest_business                       0.130642            -0.084527
# interest_creative                      -0.265018            -0.055276
# interest_health_social                 -0.114927             0.028495
# interest_research_academic              0.156530             0.151371
# risk_tolerance                          0.013729             0.015926
#
#                             problem_solving_skill  leadership_skill  \
# age                                     -0.006356         -0.000271
# experience_years                        -0.006760          0.089940
# openness                                 0.001885          0.044671
# conscientiousness                        0.016186          0.048132
# extraversion                            -0.010032          0.048842
# agreeableness                            0.019888          0.068887
# neuroticism                             -0.020832         -0.051534
# technical_skill                          0.081502          0.052190
# data_reasoning_skill                     0.066898          0.106241
# communication_skill                      0.024926          0.106585
# problem_solving_skill                    1.000000          0.003640
# leadership_skill                         0.003640          1.000000
# creative_thinking_skill                 -0.013234          0.027313
# interest_technology                      0.093032         -0.014358
# interest_business                       -0.024770         -0.011186
# interest_creative                       -0.113835         -0.036032
# interest_health_social                  -0.026284          0.028873
# interest_research_academic               0.084921          0.044894
# risk_tolerance                           0.000112          0.026876
#
#                             creative_thinking_skill  interest_technology  \
# age                                       -0.002938            -0.001837
# experience_years                           0.064499             0.000778
# openness                                   0.053043            -0.021861
# conscientiousness                          0.045457            -0.026336
# extraversion                               0.043581             0.017874
# agreeableness                              0.042491             0.001949
# neuroticism                               -0.028540            -0.007567
# technical_skill                            0.051788             0.500980
# data_reasoning_skill                       0.106068             0.363057
# communication_skill                        0.114804            -0.008657
# problem_solving_skill                     -0.013234             0.093032
# leadership_skill                           0.027313            -0.014358
# creative_thinking_skill                    1.000000            -0.000763
# interest_technology                       -0.000763             1.000000
# interest_business                         -0.039594             0.031963
# interest_creative                         -0.031139            -0.228256
# interest_health_social                    -0.007244            -0.246245
# interest_research_academic                 0.071722             0.031146
# risk_tolerance                            -0.018058            -0.012772
#
#                             interest_business  interest_creative  \
# age                                  0.022271           0.012513
# experience_years                    -0.037413          -0.023057
# openness                            -0.039331          -0.032376
# conscientiousness                   -0.035733          -0.034089
# extraversion                        -0.053437          -0.024869
# agreeableness                       -0.017088          -0.033996
# neuroticism                          0.054146           0.030094
# technical_skill                      0.118159          -0.216339
# data_reasoning_skill                 0.130642          -0.265018
# communication_skill                 -0.084527          -0.055276
# problem_solving_skill               -0.024770          -0.113835
# leadership_skill                    -0.011186          -0.036032
# creative_thinking_skill             -0.039594          -0.031139
# interest_technology                  0.031963          -0.228256
# interest_business                    1.000000          -0.183960
# interest_creative                   -0.183960           1.000000
# interest_health_social              -0.234828          -0.133614
# interest_research_academic          -0.188869          -0.280875
# risk_tolerance                       0.010707           0.009589
#
#                             interest_health_social  \
# age                                       0.005148
# experience_years                          0.001227
# openness                                 -0.006859
# conscientiousness                        -0.001525
# extraversion                              0.019669
# agreeableness                            -0.005418
# neuroticism                               0.013251
# technical_skill                          -0.157306
# data_reasoning_skill                     -0.114927
# communication_skill                       0.028495
# problem_solving_skill                    -0.026284
# leadership_skill                          0.028873
# creative_thinking_skill                  -0.007244
# interest_technology                      -0.246245
# interest_business                        -0.234828
# interest_creative                        -0.133614
# interest_health_social                    1.000000
# interest_research_academic                0.219265
# risk_tolerance                           -0.023669
#
#                             interest_research_academic  risk_tolerance
# age                                          -0.030942       -0.000849
# experience_years                              0.061394        0.008057
# openness                                      0.074745        0.001764
# conscientiousness                             0.049581       -0.003470
# extraversion                                  0.063608       -0.012575
# agreeableness                                 0.070478       -0.007328
# neuroticism                                  -0.076756        0.008726
# technical_skill                               0.061916        0.014422
# data_reasoning_skill                          0.156530        0.013729
# communication_skill                           0.151371        0.015926
# problem_solving_skill                         0.084921        0.000112
# leadership_skill                              0.044894        0.026876
# creative_thinking_skill                       0.071722       -0.018058
# interest_technology                           0.031146       -0.012772
# interest_business                            -0.188869        0.010707
# interest_creative                            -0.280875        0.009589
# interest_health_social                        0.219265       -0.023669
# interest_research_academic                    1.000000       -0.001609
# risk_tolerance                               -0.001609        1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,cmap="Blues")
plt.title('Correlation Heatmap (Numeric Features)')
plt.show()

# %%
from scipy.stats import chi2_contingency
target = "career_cluster"
categorical_col=df.select_dtypes(include=['object']).columns
results = []
for col in categorical_col:
    contingency_table = pd.crosstab(df[col], df[target])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    results.append({
        "feature": col,
        "chi_square": round(chi2, 3),
        "p_value": round(p, 6),
        "degrees_of_freedom": dof,
        "significant_at_0.05": p < 0.05
    })
chi_square_df = pd.DataFrame(results).sort_values("p_value")
chi_square_df
# Out:
#                  feature  chi_square   p_value  degrees_of_freedom  \
# 4         career_cluster   42594.000  0.000000                  36
# 3  preferred_environment       9.472  0.148730                   6
# 2   preferred_work_style       7.246  0.298717                   6
# 0        education_level       8.849  0.715758                  12
# 1         field_of_study      36.505  0.887453                  48
#
#    significant_at_0.05
# 4                 True
# 3                False
# 2                False
# 0                False
# 1                False

# %%
#Feature Engineering
df["work_life_alignment"] = (
        df["preferred_environment"].eq("flexible").astype(int) -
        df["preferred_environment"].eq("structured").astype(int) +
        df["risk_tolerance"].eq(0).astype(int) -
        df["risk_tolerance"].eq(2).astype(int)
    )
df.drop(columns=['preferred_environment','risk_tolerance'],inplace=True)

# %%
#Encoding
categorical_col=df.select_dtypes(include=['object']).columns
encode_col=categorical_col.drop('career_cluster')
df=pd.get_dummies(df,columns=encode_col,drop_first=True)

# %%
#Imbalance check
counts = df['career_cluster'].value_counts()
percent = df['career_cluster'].value_counts(normalize=True) * 100
imbalance_df = pd.DataFrame({
    'count': counts,
    'percentage': percent.round(2)
})
imbalance_df
# Out:
#                               count  percentage
# career_cluster
# Education & Social Impact      1081       15.23
# Technology & Engineering       1038       14.62
# Design & Creative Media        1032       14.54
# Healthcare & Life Sciences     1013       14.27
# Business & Management           999       14.07
# Entrepreneurship & Freelance    995       14.02
# Finance & Economics             941       13.26

# %%
imbalance_ratio = counts.max() / counts.min()
imbalance_ratio
# Out:
# 1.1487778958554729

# %%
x=df.drop(columns='career_cluster')
y=df['career_cluster']

# %%
#Train-test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,stratify=y,random_state=42)
x_train
# Out:
#        age  experience_years  openness  conscientiousness  extraversion  \
# 1426  20.0               2.0       4.0                5.0           4.0
# 5288  24.0               5.0       4.0                5.0           4.0
# 5549  27.0               0.0       3.0                4.0           3.0
# 4260  26.0               0.0       3.0                3.0           1.0
# 2379  26.0               1.0       3.0                4.0           2.0
# ...    ...               ...       ...                ...           ...
# 5089  26.0               6.0       3.0                4.0           4.0
# 6798  27.0               1.0       3.0                5.0           3.0
# 844   24.0               2.0       3.0                3.0           3.0
# 3879  21.0               2.0       3.0                3.0           1.0
# 6877  25.0               5.0       4.0                4.0           2.0
#
#       agreeableness  neuroticism  technical_skill  data_reasoning_skill  \
# 1426            4.0          1.0              3.0                   1.0
# 5288            5.0          1.0              2.0                   3.0
# 5549            5.0          1.0              4.0                   4.0
# 4260            4.0          4.0              3.0                   3.0
# 2379            3.0          2.0              3.0                   2.0
# ...             ...          ...              ...                   ...
# 5089            3.0          1.0              4.0                   4.0
# 6798            5.0          1.0              2.0                   3.0
# 844             3.0          4.0              3.0                   2.0
# 3879            1.0          3.0              2.0                   3.0
# 6877            5.0          1.0              4.0                   4.0
#
#       communication_skill  ...  education_level_Undergraduate  \
# 1426                  2.0  ...                          False
# 5288                  4.0  ...                          False
# 5549                  4.0  ...                          False
# 4260                  3.0  ...                          False
# 2379                  3.0  ...                           True
# ...                   ...  ...                            ...
# 5089                  5.0  ...                          False
# 6798                  5.0  ...                          False
# 844                   3.0  ...                           True
# 3879                  4.0  ...                           True
# 6877                  4.0  ...                          False
#
#       field_of_study_Business  field_of_study_Computer Science  \
# 1426                    False                            False
# 5288                    False                            False
# 5549                     True                            False
# 4260                    False                            False
# 2379                    False                            False
# ...                       ...                              ...
# 5089                    False                            False
# 6798                    False                            False
# 844                     False                            False
# 3879                    False                            False
# 6877                    False                            False
#
#       field_of_study_Design  field_of_study_Economics  \
# 1426                  False                     False
# 5288                  False                      True
# 5549                  False                     False
# 4260                  False                     False
# 2379                  False                     False
# ...                     ...                       ...
# 5089                  False                     False
# 6798                  False                     False
# 844                   False                     False
# 3879                  False                     False
# 6877                  False                     False
#
#       field_of_study_Engineering  field_of_study_IT  field_of_study_Other  \
# 1426                       False              False                 False
# 5288                       False              False                 False
# 5549                       False              False                 False
# 4260                       False              False                 False
# 2379                       False              False                 False
# ...                          ...                ...                   ...
# 5089                       False              False                 False
# 6798                        True              False                 False
# 844                        False              False                 False
# 3879                       False              False                 False
# 6877                        True              False                 False
#
#       field_of_study_Psychology  preferred_work_style_individual
# 1426                      False                            False
# 5288                      False                             True
# 5549                      False                             True
# 4260                       True                            False
# 2379                      False                            False
# ...                         ...                              ...
# 5089                       True                            False
# 6798                      False                             True
# 844                        True                            False
# 3879                      False                            False
# 6877                      False                             True
#
# [4969 rows x 30 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# Model training
model = RandomForestClassifier(
    n_estimators=600,
    max_depth=9,               
    min_samples_leaf=6,      
    max_features=0.3,          
    ccp_alpha=0.0005,          
    random_state=42,
    n_jobs=-1
)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
#Model evaluation
from sklearn.metrics import classification_report,accuracy_score
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.8323943661971831

# %%
# Get predictions for both sets
train_preds = model.predict(x_train)
test_preds = model.predict(x_test)

# Calculate accuracy
train_acc = accuracy_score(y_train, train_preds)
test_acc = accuracy_score(y_test, test_preds)
print(f"Training Accuracy: {train_acc * 100:.2f}%")
print(f"Testing Accuracy: {test_acc * 100:.2f}%")
# Out:
# Training Accuracy: 85.71%
# Testing Accuracy: 83.24%

# %%
#Report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#                               precision    recall  f1-score   support
#
#        Business & Management       0.79      0.75      0.77       300
#      Design & Creative Media       0.97      0.97      0.97       310
#    Education & Social Impact       0.76      0.77      0.76       324
# Entrepreneurship & Freelance       0.85      0.79      0.82       299
#          Finance & Economics       0.78      0.79      0.78       282
#   Healthcare & Life Sciences       0.76      0.81      0.78       304
#     Technology & Engineering       0.92      0.95      0.94       311
#
#                     accuracy                           0.83      2130
#                    macro avg       0.83      0.83      0.83      2130
#                 weighted avg       0.83      0.83      0.83      2130

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

class_names = model.classes_
# Create confusion matrix
cm = confusion_matrix(y_test, y_pred)
# Plot
plt.figure(figsize=(10,8))
sns.heatmap(
    cm,annot=True,
    cmap="Blues",fmt="d",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
importances = pd.Series(model.feature_importances_,index=x_train.columns)
top_features = importances.nlargest(15).sort_values()
plt.figure(figsize=(10, 6))
plt.barh(top_features.index,top_features.values)
plt.title("Top 15 Features")
plt.xlabel("Importance Score")
plt.show()

# %%
#Model Saving
import joblib
joblib.dump(model, 'career_model.joblib') # Save the trained model
feature_columns = list(x.columns)
joblib.dump(feature_columns, 'feature_columns.joblib') # Save feature columns
df_original = pd.read_csv('career.csv')
risk_tolerance_mapping = {'Low': 0, 'Medium': 1, 'High': 2}
joblib.dump(risk_tolerance_mapping, 'risk_tolerance_mapping.joblib')
print("\nFiles created:")
print("  - career_model.joblib")
print("  - feature_columns.joblib")
print("  - risk_tolerance_mapping.joblib")
# Out:
# Files created:
#   - career_model.joblib
#   - feature_columns.joblib
#   - risk_tolerance_mapping.joblib
