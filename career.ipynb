# %%
#Data Loading and Inspection
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('career.csv') 
df
# Out:
#      user_id              name   age education_level    field_of_study  \
# 0     U00001               NaN   NaN     High School               NaN
# 1     U00002               NaN   NaN     High School  Computer Science
# 2     U00003       Anika Patel  24.0        Graduate        Psychology
# 3     U00004     Joseph Sharma  27.0     High School        Psychology
# 4     U00005        Anika Iyer  23.0        Graduate                IT
# ...      ...               ...   ...             ...               ...
# 7094  U07095        Emma Brown  27.0        Graduate             Other
# 7095  U07096    William Martin  25.0        Graduate             Other
# 7096  U07097    David Thompson  29.0   Undergraduate             Other
# 7097  U07098    James Thompson  25.0     High School             Other
# 7098  U07099  William Thompson  25.0     High School             Other
#
#      experience_years  openness  conscientiousness  extraversion  \
# 0             1 years       4.0                NaN           2.0
# 1             0 years       5.0                3.0           3.0
# 2             0 years       2.0                4.0           3.0
# 3             2 years       3.0                3.0           3.0
# 4             3 years       1.0                4.0           3.0
# ...               ...       ...                ...           ...
# 7094          0 years       2.0                1.0           4.0
# 7095          3 years       3.0                2.0           4.0
# 7096          2 years       4.0                3.0           5.0
# 7097          1 years       5.0                3.0           5.0
# 7098          5 years       2.0                1.0           5.0
#
#       agreeableness  ...  creative_thinking_skill  interest_technology  \
# 0               3.0  ...                      3.0                 15.0
# 1               2.0  ...                      2.0                 53.0
# 2               4.0  ...                      3.0                 17.0
# 3               4.0  ...                      2.0                 55.0
# 4               3.0  ...                      2.0                 34.0
# ...             ...  ...                      ...                  ...
# 7094            3.0  ...                      5.0                 65.0
# 7095            5.0  ...                      2.0                 36.0
# 7096            3.0  ...                      3.0                 23.0
# 7097            3.0  ...                      1.0                 90.0
# 7098            2.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 0                  32.0               39.0                    24.0
# 1                  39.0               74.0                    52.0
# 2                  43.0               81.0                    29.0
# 3                  83.0               33.0                    45.0
# 4                  54.0               38.0                    32.0
# ...                 ...                ...                     ...
# 7094               99.0               98.0                    12.0
# 7095               40.0               76.0                    43.0
# 7096               42.0               10.0                    41.0
# 7097               72.0               33.0                    86.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 0                           49.0            individual             structured
# 1                           26.0            individual               flexible
# 2                           54.0         collaborative               flexible
# 3                           68.0            individual               flexible
# 4                           52.0         collaborative             structured
# ...                          ...                   ...                    ...
# 7094                        95.0            individual             structured
# 7095                        33.0         collaborative               flexible
# 7096                        96.0            individual               flexible
# 7097                        34.0            individual             structured
# 7098                        78.0            individual             structured
#
#       risk_tolerance                career_cluster
# 0                NaN     Education & Social Impact
# 1                low       Design & Creative Media
# 2                low       Design & Creative Media
# 3             medium         Business & Management
# 4               high    Healthcare & Life Sciences
# ...              ...                           ...
# 7094            high         Business & Management
# 7095            high  Entrepreneurship & Freelance
# 7096          medium           Finance & Economics
# 7097          medium     Education & Social Impact
# 7098             low      Technology & Engineering
#
# [7099 rows x 26 columns]

# %%
print(df.shape)
# Out:
# (7099, 26)

# %%
print(df.columns)
# Out:
# Index(['user_id', 'name', 'age', 'education_level', 'field_of_study',
#        'experience_years', 'openness', 'conscientiousness', 'extraversion',
#        'agreeableness', 'neuroticism', 'technical_skill',
#        'data_reasoning_skill', 'communication_skill', 'problem_solving_skill',
#        'leadership_skill', 'creative_thinking_skill', 'interest_technology',
#        'interest_business', 'interest_creative', 'interest_health_social',
#        'interest_research_academic', 'preferred_work_style',
#        'preferred_environment', 'risk_tolerance', 'career_cluster'],
#       dtype='object')

# %%
print(df.head())
# Out:
#   user_id           name   age education_level    field_of_study  \
# 0  U00001            NaN   NaN     High School               NaN
# 1  U00002            NaN   NaN     High School  Computer Science
# 2  U00003    Anika Patel  24.0        Graduate        Psychology
# 3  U00004  Joseph Sharma  27.0     High School        Psychology
# 4  U00005     Anika Iyer  23.0        Graduate                IT
#
#   experience_years  openness  conscientiousness  extraversion  agreeableness  \
# 0          1 years       4.0                NaN           2.0            3.0
# 1          0 years       5.0                3.0           3.0            2.0
# 2          0 years       2.0                4.0           3.0            4.0
# 3          2 years       3.0                3.0           3.0            4.0
# 4          3 years       1.0                4.0           3.0            3.0
#
#    ...  creative_thinking_skill  interest_technology  interest_business  \
# 0  ...                      3.0                 15.0               32.0
# 1  ...                      2.0                 53.0               39.0
# 2  ...                      3.0                 17.0               43.0
# 3  ...                      2.0                 55.0               83.0
# 4  ...                      2.0                 34.0               54.0
#
#    interest_creative  interest_health_social  interest_research_academic  \
# 0               39.0                    24.0                        49.0
# 1               74.0                    52.0                        26.0
# 2               81.0                    29.0                        54.0
# 3               33.0                    45.0                        68.0
# 4               38.0                    32.0                        52.0
#
#    preferred_work_style  preferred_environment  risk_tolerance  \
# 0            individual             structured             NaN
# 1            individual               flexible             low
# 2         collaborative               flexible             low
# 3            individual               flexible          medium
# 4         collaborative             structured            high
#
#                career_cluster
# 0   Education & Social Impact
# 1     Design & Creative Media
# 2     Design & Creative Media
# 3       Business & Management
# 4  Healthcare & Life Sciences
#
# [5 rows x 26 columns]

# %%
print(df.tail())
# Out:
#      user_id              name   age education_level field_of_study  \
# 7094  U07095        Emma Brown  27.0        Graduate          Other
# 7095  U07096    William Martin  25.0        Graduate          Other
# 7096  U07097    David Thompson  29.0   Undergraduate          Other
# 7097  U07098    James Thompson  25.0     High School          Other
# 7098  U07099  William Thompson  25.0     High School          Other
#
#      experience_years  openness  conscientiousness  extraversion  \
# 7094          0 years       2.0                1.0           4.0
# 7095          3 years       3.0                2.0           4.0
# 7096          2 years       4.0                3.0           5.0
# 7097          1 years       5.0                3.0           5.0
# 7098          5 years       2.0                1.0           5.0
#
#       agreeableness  ...  creative_thinking_skill  interest_technology  \
# 7094            3.0  ...                      5.0                 65.0
# 7095            5.0  ...                      2.0                 36.0
# 7096            3.0  ...                      3.0                 23.0
# 7097            3.0  ...                      1.0                 90.0
# 7098            2.0  ...                      3.0                 87.0
#
#       interest_business  interest_creative  interest_health_social  \
# 7094               99.0               98.0                    12.0
# 7095               40.0               76.0                    43.0
# 7096               42.0               10.0                    41.0
# 7097               72.0               33.0                    86.0
# 7098               12.0               16.0                    88.0
#
#       interest_research_academic  preferred_work_style  preferred_environment  \
# 7094                        95.0            individual             structured
# 7095                        33.0         collaborative               flexible
# 7096                        96.0            individual               flexible
# 7097                        34.0            individual             structured
# 7098                        78.0            individual             structured
#
#       risk_tolerance                career_cluster
# 7094            high         Business & Management
# 7095            high  Entrepreneurship & Freelance
# 7096          medium           Finance & Economics
# 7097          medium     Education & Social Impact
# 7098             low      Technology & Engineering
#
# [5 rows x 26 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7099 entries, 0 to 7098
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user_id                     6980 non-null   object
#  1   name                        7000 non-null   object
#  2   age                         7007 non-null   float64
#  3   education_level             7020 non-null   object
#  4   field_of_study              7016 non-null   object
#  5   experience_years            7023 non-null   object
#  6   openness                    7006 non-null   float64
#  7   conscientiousness           6999 non-null   float64
#  8   extraversion                7007 non-null   float64
#  9   agreeableness               7017 non-null   float64
#  10  neuroticism                 6999 non-null   float64
#  11  technical_skill             7007 non-null   float64
#  12  data_reasoning_skill        7005 non-null   float64
#  13  communication_skill         7015 non-null   float64
#  14  problem_solving_skill       6995 non-null   float64
#  15  leadership_skill            7001 non-null   float64
#  16  creative_thinking_skill     7009 non-null   float64
#  17  interest_technology         7018 non-null   float64
#  18  interest_business           6999 non-null   float64
#  19  interest_creative           7017 non-null   float64
#  20  interest_health_social      6999 non-null   float64
#  21  interest_research_academic  7010 non-null   float64
#  22  preferred_work_style        7021 non-null   object
#  23  preferred_environment       6994 non-null   object
#  24  risk_tolerance              6999 non-null   object
#  25  career_cluster              7099 non-null   object
# dtypes: float64(17), object(9)
# memory usage: 1.4+ MB
# None

# %%
df.dtypes
# Out:
# user_id                        object
# name                           object
# age                           float64
# education_level                object
# field_of_study                 object
# experience_years               object
# openness                      float64
# conscientiousness             float64
# extraversion                  float64
# agreeableness                 float64
# neuroticism                   float64
# technical_skill               float64
# data_reasoning_skill          float64
# communication_skill           float64
# problem_solving_skill         float64
# leadership_skill              float64
# creative_thinking_skill       float64
# interest_technology           float64
# interest_business             float64
# interest_creative             float64
# interest_health_social        float64
# interest_research_academic    float64
# preferred_work_style           object
# preferred_environment          object
# risk_tolerance                 object
# career_cluster                 object
# dtype: object

# %%
df[['openness','conscientiousness','extraversion','agreeableness','neuroticism']].describe()
# Out:
#           openness  conscientiousness  extraversion  agreeableness  \
# count  7006.000000        6999.000000   7007.000000    7017.000000
# mean      3.611904           3.613373      2.668046       3.611087
# std       0.984662           0.977000      0.971465       0.983737
# min       1.000000           1.000000      1.000000       1.000000
# 25%       3.000000           3.000000      2.000000       3.000000
# 50%       4.000000           4.000000      3.000000       4.000000
# 75%       4.000000           4.000000      3.000000       4.000000
# max       5.000000           5.000000      5.000000       5.000000
#
#        neuroticism
# count  6999.000000
# mean      2.369338
# std       0.980101
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       5.000000

# %%
df[['technical_skill', 'data_reasoning_skill', 'communication_skill',
    'problem_solving_skill', 'leadership_skill', 'creative_thinking_skill']].describe()
# Out:
#        technical_skill  data_reasoning_skill  communication_skill  \
# count      7007.000000           7005.000000          7015.000000
# mean          2.406451              2.655960             2.935139
# std           1.167430              1.313771             1.204230
# min           0.000000              0.000000             0.000000
# 25%           2.000000              2.000000             2.000000
# 50%           2.000000              3.000000             3.000000
# 75%           3.000000              4.000000             4.000000
# max           5.000000              5.000000             5.000000
#
#        problem_solving_skill  leadership_skill  creative_thinking_skill
# count            6995.000000       7001.000000              7009.000000
# mean                3.498213          2.650193                 2.641746
# std                 0.892309          1.014349                 1.007210
# min                 0.000000          0.000000                 0.000000
# 25%                 3.000000          2.000000                 2.000000
# 50%                 4.000000          3.000000                 3.000000
# 75%                 4.000000          3.000000                 3.000000
# max                 5.000000          5.000000                 5.000000

# %%
df[['interest_technology', 'interest_business', 'interest_creative', 
    'interest_health_social', 'interest_research_academic']].describe()
# Out:
#        interest_technology  interest_business  interest_creative  \
# count          7018.000000        6999.000000        7017.000000
# mean             48.943716          53.480783          44.651275
# std              18.604947          20.779766          20.659804
# min               0.000000           5.000000           0.000000
# 25%              35.000000          35.000000          30.000000
# 50%              45.000000          52.000000          40.000000
# 75%              60.000000          71.000000          52.000000
# max             100.000000         101.000000         100.000000
#
#        interest_health_social  interest_research_academic
# count             6999.000000                 7010.000000
# mean                40.043578                   47.655064
# std                 19.269162                   16.132574
# min                  0.000000                    0.000000
# 25%                 26.000000                   37.000000
# 50%                 36.000000                   46.000000
# 75%                 51.000000                   60.000000
# max                 99.000000                  100.000000

# %%
#Converting to integer type.
df['experience_years']=df['experience_years'].str.replace("years","").astype('Int64')
df['experience_years']
# Out:
# 0       1
# 1       0
# 2       0
# 3       2
# 4       3
#        ..
# 7094    0
# 7095    3
# 7096    2
# 7097    1
# 7098    5
# Name: experience_years, Length: 7099, dtype: Int64

# %%
#Dropping useless columns
df.drop(columns=['user_id','name'], inplace=True)

# %%
# Map categorical risk tolerance levels to numerical values
df['risk_tolerance']=df['risk_tolerance'].map({'low':0, 'medium':1, 'high':2})
df['risk_tolerance'].dtype
# Out:
# dtype('float64')

# %%
# Define numeric and categorical features for preprocessing
numeric_features = [
    'age', 'experience_years', 'openness', 'conscientiousness', 'extraversion',
    'agreeableness', 'neuroticism', 'technical_skill', 'data_reasoning_skill',
    'communication_skill', 'problem_solving_skill', 'leadership_skill',
    'creative_thinking_skill', 'interest_technology', 'interest_business',
    'interest_creative', 'interest_health_social', 'interest_research_academic',
    'risk_tolerance'
]

categorical_features = [
    'education_level', 'field_of_study', 
    'preferred_work_style', 'preferred_environment'
]
df_for_stats = df.copy()

# %%
#Checking for missing values
df.isna().sum()
# Out:
# age                            92
# education_level                79
# field_of_study                 83
# experience_years               76
# openness                       93
# conscientiousness             100
# extraversion                   92
# agreeableness                  82
# neuroticism                   100
# technical_skill                92
# data_reasoning_skill           94
# communication_skill            84
# problem_solving_skill         104
# leadership_skill               98
# creative_thinking_skill        90
# interest_technology            81
# interest_business             100
# interest_creative              82
# interest_health_social        100
# interest_research_academic     89
# preferred_work_style           78
# preferred_environment         105
# risk_tolerance                100
# career_cluster                  0
# dtype: int64

# %%
#Printing unique values in features.
l = ['age','education_level','field_of_study', 'experience_years', 'openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism', 'technical_skill', 'data_reasoning_skill', 'communication_skill', 'problem_solving_skill', 'leadership_skill', 'creative_thinking_skill', 'interest_technology', 'interest_business', 'interest_creative', 'interest_health_social', 'interest_research_academic', 'preferred_work_style', 'preferred_environment', 'risk_tolerance']
for i in l:
    print(i, ":", df[i].unique(), "\n")
# Out:
# age : [nan 24. 27. 23. 21. 25. 30. 20. 18. 22. 26. 28. 40. 19. 29. 15. 35.]
#
# education_level : ['High School' 'Graduate' 'Undergraduate' nan]
#
# field_of_study : [nan 'Computer Science' 'Psychology' 'IT' 'Design' 'Biology' 'Business'
#  'Economics' 'Engineering' 'Other']
#
# experience_years : <IntegerArray>
# [1, 0, 2, 3, <NA>, 4, 5, 9, 6, 7, 8, 10]
# Length: 12, dtype: Int64
#
# openness : [ 4.  5.  2.  3.  1. nan]
#
# conscientiousness : [nan  3.  4.  2.  5.  1.]
#
# extraversion : [ 2.  3.  1.  4.  5. nan]
#
# agreeableness : [ 3.  2.  4.  5.  1. nan]
#
# neuroticism : [nan  2.  3.  1.  5.  4.]
#
# technical_skill : [ 2.  1.  0.  3. nan  4.  5.]
#
# data_reasoning_skill : [ 1.  0.  3.  2.  4.  5. nan]
#
# communication_skill : [nan  3.  2.  1.  4.  5.  0.]
#
# problem_solving_skill : [ 3.  4.  5.  2.  0. nan  1.]
#
# leadership_skill : [ 2.  4.  3. nan  5.  1.  0.]
#
# creative_thinking_skill : [ 3.  2.  4.  1.  5.  0. nan]
#
# interest_technology : [ 15.  53.  17.  55.  34.  46.  35.  47.  39.  68.  22.  51.  66.  28.
#   42.  nan  31.  49.  44.  84.  85.  86.  37.  21.  25.  71.  29.  24.
#   92.  27.  91.  73.  64.  41.  76.  57.  50.  78.  58.  23.  74.  45.
#   56.  83.  20.  59.  30.  61.  54.  69.  38.  75.  33.  81. 100.  52.
#   48.  72.  43.  67.  79.  90.  60.  77.  16.  32.  40.  26.  63.  36.
#   70.  18.  97.   6.  65.  62.  80.  19.  82.   9.  93.  89.  96.  87.
#   88.  14.  98.  11.   8.  13.  94.  95.  10.   7.  99.   0.  12.]
#
# interest_business : [ 32.  39.  43.  83.  54.  73.  94.  67.  38.  65.  51.  57.  91.  61.
#   52.  75.  44.  64.  71.  26.  47.  55.  nan  48.  63.  49.  40.  66.
#   30.  42.  79.  41.  60.  82.  35.  53.  74.  50.  72.  56.  85.  88.
#   33.  70.  62.  19.  34.  80.  78.  68.  76.  77.  45.  36.  37.  59.
#   86.  58.  15.  27.  21.  92.  84.  69.  28. 100.  97.  31.  46.  99.
#   23.  29.  87.  22.  96.  81.  90.  16.  89.  18.  25.   5.  24.  95.
#   93.  20.  10.  13.  11.   7.  98. 101.  12.]
#
# interest_creative : [ 39.  74.  81.  33.  38.  34.  25.  68.  51.  69.  nan  41.  57.  89.
#   15.  35.  79.  52.  37.  53.  23.  17.  42. 100.  92.  26.  82.  30.
#   59.  83.  32.  36.  49.  45.  24.  58.  87.  20.  93.  48.  56.  40.
#   50.  84.  44.  76.  90.  71.  46.  28.  12.  60.  77.  27.  47.  95.
#   70.  31.  21.  66.  43.  29.  72.  13.  86.  62.  18.  80.  19.  22.
#   61.  63.  78.  10.  73.  91.  75.  64.  85.  54.  94.  55.  14.  65.
#   88.   8.  99.  98.  96.   9.  16.  97.  67.  11.   5.   6.   0.   1.
#    7.]
#
# interest_health_social : [24. 52. 29. 45. 32. 68. 48. 15. 25. 36. nan 35. 40. 21. 33. 37. 39. 27.
#  44. 53. 57. 16. 22. 49. 28. 19. 14. 55. 47.  0. 34. 43. 46. 58. 63. 42.
#  77. 41. 65. 56. 51. 62. 64. 74. 60. 31. 38. 26. 18.  7. 30. 23. 71. 61.
#  59. 13. 17. 69. 54. 50.  8. 12. 20.  9. 10. 11. 72.  4. 66.  6. 78. 90.
#  89. 75. 79. 70.  5. 81. 73. 67. 80.  1.  3.  2. 76. 82. 88. 91. 85. 83.
#  98. 95. 93. 96. 97. 86. 92. 87. 94. 99. 84.]
#
# interest_research_academic : [ 49.  26.  54.  68.  52.  47.  77.  56.  85.  35.  58.  46.  53.  76.
#   48.  32.  37.  64.  14.  29.  23.  36.  38.  11.  50.  44.  61.  60.
#   59.  84.  31.  71.  66.  34.  45.  nan   2.  57.  15.  51.  12.  41.
#   43.  63.  55.  42.  28.  40.  65.  62.  39.  69.  33.  30.  70.  27.
#   72.  24.  74.  25.  75.  18.  20.   8.  21.  83.   7.   6.  13.  78.
#   67.  19.  22.  79.  81.   9.  17.  16.   4.  73.  80.   5.  82.   3.
#    1.  10.   0.  87.  89.  86.  97.  93.  94.  92.  96. 100.  95.]
#
# preferred_work_style : ['individual' 'collaborative' nan]
#
# preferred_environment : ['structured' 'flexible' nan]
#
# risk_tolerance : [nan  0.  1.  2.]

# %%
#Filling missing values
median_cols = [
    'age', 'experience_years', 'openness', 'conscientiousness',
    'extraversion', 'agreeableness', 'neuroticism',
    'technical_skill', 'data_reasoning_skill', 'communication_skill',
    'problem_solving_skill', 'leadership_skill', 'creative_thinking_skill',
    'interest_technology', 'interest_business', 'interest_creative',
    'interest_health_social', 'interest_research_academic'
]

for col in median_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
mode_cols = [
    'education_level', 'field_of_study',
    'preferred_work_style', 'preferred_environment',
    'risk_tolerance'
]

for col in mode_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
#IQR
num_cols = df.select_dtypes(include=['int64','float64']).columns
outlier_len = {}
for i in num_cols:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1 
    outliers = df[(df[i] < Q1 - 1.5*IQR) | (df[i] > Q3 + 1.5*IQR)]
    outlier_len[i] = len(outliers)
outlier_len
# Out:
# {'age': 68,
#  'experience_years': 710,
#  'openness': 140,
#  'conscientiousness': 122,
#  'extraversion': 133,
#  'agreeableness': 132,
#  'neuroticism': 111,
#  'technical_skill': 569,
#  'data_reasoning_skill': 0,
#  'communication_skill': 0,
#  'problem_solving_skill': 126,
#  'leadership_skill': 250,
#  'creative_thinking_skill': 249,
#  'interest_technology': 44,
#  'interest_business': 0,
#  'interest_creative': 524,
#  'interest_health_social': 126,
#  'interest_research_academic': 21,
#  'risk_tolerance': 0}

# %%
plt.boxplot(df['age'])
plt.title('Age Outliers')
plt.show()

# %%
plt.boxplot(df['experience_years'])
plt.title('Experience Years Outliers')
plt.show()

# %%
#Cap experience years to be logically consistent with age
df['experience_years'] = np.minimum(df['experience_years'],df['age'] - 18)
df['experience_years'] = df['experience_years'].clip(lower=0)

# %%
# Scale interests from 0-100 to 0-5 to match personality/skill scale
from sklearn.preprocessing import MinMaxScaler

interest_columns = [
    'interest_technology', 'interest_business', 'interest_creative',
    'interest_health_social', 'interest_research_academic'
]
scaler = MinMaxScaler(feature_range=(0, 5))
df[interest_columns] = scaler.fit_transform(df[interest_columns]).round(2)

# Save scaler for app.py to use on new input
import joblib
joblib.dump(scaler, 'interest_scaler.joblib')
# Out:
# ['interest_scaler.joblib']

# %%
#Visualization
df1=df['career_cluster'].value_counts().sort_values(ascending=False)
print(df1)
plt.barh(df1.index,df1.values)
plt.xlabel('Career Cluster')
plt.ylabel('Count')
plt.title('Distribution of Career Clusters')
plt.show()
# Out:
# career_cluster
# Education & Social Impact       1081
# Technology & Engineering        1038
# Design & Creative Media         1032
# Healthcare & Life Sciences      1013
# Business & Management            999
# Entrepreneurship & Freelance     995
# Finance & Economics              941
# Name: count, dtype: int64

# %%
personality_cols = ['openness', 'conscientiousness', 'extraversion','agreeableness', 'neuroticism']
personality_mean = df.groupby('career_cluster')[personality_cols].mean().mean(axis=1)
plt.figure(figsize=(9,5))
plt.plot(personality_mean.index, personality_mean.values, marker='o')
plt.xlabel("Career Cluster")
plt.ylabel("Average Personality Score")
plt.title("Average Personality Profile across Career Clusters")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
skill_cols = [ 'technical_skill', 'data_reasoning_skill', 'communication_skill','problem_solving_skill', 'leadership_skill', 'creative_thinking_skill']
skill_mean = df.groupby('career_cluster')[skill_cols].mean().mean(axis=1)
plt.figure(figsize=(9,5))
plt.bar(skill_mean.index, skill_mean.values, color='teal')
plt.xlabel("Career Cluster")
plt.ylabel("Average Skill Level")
plt.title("Average Skill Level across Career Clusters")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
interest_cols = ['interest_technology', 'interest_business','interest_creative', 
                 'interest_health_social','interest_research_academic']
interest_mean = df.groupby('career_cluster')[interest_cols].mean().mean(axis=1)
plt.figure(figsize=(9,5))
plt.plot(interest_mean.index, interest_mean.values, marker='o', color='purple')
plt.xlabel("Career Cluster")
plt.ylabel("Average Interest Level")
plt.title("Average Interest Level across Career Clusters")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Correlation
num_cols = df.select_dtypes(include=['int64','float64']).columns
corr = df[num_cols].corr()
corr
# Out:
#                                  age  experience_years  openness  \
# age                         1.000000          0.311173 -0.021848
# experience_years            0.311173          1.000000  0.059893
# openness                   -0.021848          0.059893  1.000000
# conscientiousness          -0.022669          0.060711  0.068086
# extraversion               -0.013968          0.094651  0.050813
# agreeableness              -0.016703          0.056437  0.065517
# neuroticism                 0.031736         -0.060455 -0.047694
# technical_skill            -0.029204          0.085728  0.048939
# data_reasoning_skill       -0.037814          0.161141  0.110082
# communication_skill        -0.027393          0.168887  0.122922
# problem_solving_skill      -0.006356         -0.006760  0.001885
# leadership_skill           -0.000271          0.089940  0.044671
# creative_thinking_skill    -0.002938          0.064499  0.053043
# interest_technology        -0.001837          0.000778 -0.021861
# interest_business           0.022365         -0.037550 -0.039466
# interest_creative           0.012513         -0.023057 -0.032376
# interest_health_social      0.005117          0.001426 -0.006713
# interest_research_academic -0.030942          0.061394  0.074745
# risk_tolerance             -0.000849          0.008057  0.001764
#
#                             conscientiousness  extraversion  agreeableness  \
# age                                 -0.022669     -0.013968      -0.016703
# experience_years                     0.060711      0.094651       0.056437
# openness                             0.068086      0.050813       0.065517
# conscientiousness                    1.000000      0.067943       0.069318
# extraversion                         0.067943      1.000000       0.052872
# agreeableness                        0.069318      0.052872       1.000000
# neuroticism                         -0.056983     -0.047618      -0.082183
# technical_skill                      0.055440      0.056944       0.071396
# data_reasoning_skill                 0.109482      0.117566       0.107203
# communication_skill                  0.135066      0.132071       0.129009
# problem_solving_skill                0.016186     -0.010032       0.019888
# leadership_skill                     0.048132      0.048842       0.068887
# creative_thinking_skill              0.045457      0.043581       0.042491
# interest_technology                 -0.026336      0.017874       0.001949
# interest_business                   -0.035845     -0.053561      -0.017186
# interest_creative                   -0.034089     -0.024869      -0.033996
# interest_health_social              -0.001405      0.019761      -0.005190
# interest_research_academic           0.049581      0.063608       0.070478
# risk_tolerance                      -0.003470     -0.012575      -0.007328
#
#                             neuroticism  technical_skill  \
# age                            0.031736        -0.029204
# experience_years              -0.060455         0.085728
# openness                      -0.047694         0.048939
# conscientiousness             -0.056983         0.055440
# extraversion                  -0.047618         0.056944
# agreeableness                 -0.082183         0.071396
# neuroticism                    1.000000        -0.046481
# technical_skill               -0.046481         1.000000
# data_reasoning_skill          -0.123666         0.437928
# communication_skill           -0.117951         0.146461
# problem_solving_skill         -0.020832         0.081502
# leadership_skill              -0.051534         0.052190
# creative_thinking_skill       -0.028540         0.051788
# interest_technology           -0.007567         0.500980
# interest_business              0.054257         0.117870
# interest_creative              0.030094        -0.216339
# interest_health_social         0.013143        -0.156994
# interest_research_academic    -0.076756         0.061916
# risk_tolerance                 0.008726         0.014422
#
#                             data_reasoning_skill  communication_skill  \
# age                                    -0.037814            -0.027393
# experience_years                        0.161141             0.168887
# openness                                0.110082             0.122922
# conscientiousness                       0.109482             0.135066
# extraversion                            0.117566             0.132071
# agreeableness                           0.107203             0.129009
# neuroticism                            -0.123666            -0.117951
# technical_skill                         0.437928             0.146461
# data_reasoning_skill                    1.000000             0.289573
# communication_skill                     0.289573             1.000000
# problem_solving_skill                   0.066898             0.024926
# leadership_skill                        0.106241             0.106585
# creative_thinking_skill                 0.106068             0.114804
# interest_technology                     0.363057            -0.008657
# interest_business                       0.130480            -0.084734
# interest_creative                      -0.265018            -0.055276
# interest_health_social                 -0.114561             0.028864
# interest_research_academic              0.156530             0.151371
# risk_tolerance                          0.013729             0.015926
#
#                             problem_solving_skill  leadership_skill  \
# age                                     -0.006356         -0.000271
# experience_years                        -0.006760          0.089940
# openness                                 0.001885          0.044671
# conscientiousness                        0.016186          0.048132
# extraversion                            -0.010032          0.048842
# agreeableness                            0.019888          0.068887
# neuroticism                             -0.020832         -0.051534
# technical_skill                          0.081502          0.052190
# data_reasoning_skill                     0.066898          0.106241
# communication_skill                      0.024926          0.106585
# problem_solving_skill                    1.000000          0.003640
# leadership_skill                         0.003640          1.000000
# creative_thinking_skill                 -0.013234          0.027313
# interest_technology                      0.093032         -0.014358
# interest_business                       -0.024738         -0.011318
# interest_creative                       -0.113835         -0.036032
# interest_health_social                  -0.026282          0.028977
# interest_research_academic               0.084921          0.044894
# risk_tolerance                           0.000112          0.026876
#
#                             creative_thinking_skill  interest_technology  \
# age                                       -0.002938            -0.001837
# experience_years                           0.064499             0.000778
# openness                                   0.053043            -0.021861
# conscientiousness                          0.045457            -0.026336
# extraversion                               0.043581             0.017874
# agreeableness                              0.042491             0.001949
# neuroticism                               -0.028540            -0.007567
# technical_skill                            0.051788             0.500980
# data_reasoning_skill                       0.106068             0.363057
# communication_skill                        0.114804            -0.008657
# problem_solving_skill                     -0.013234             0.093032
# leadership_skill                           0.027313            -0.014358
# creative_thinking_skill                    1.000000            -0.000763
# interest_technology                       -0.000763             1.000000
# interest_business                         -0.039653             0.031835
# interest_creative                         -0.031139            -0.228256
# interest_health_social                    -0.007109            -0.246319
# interest_research_academic                 0.071722             0.031146
# risk_tolerance                            -0.018058            -0.012772
#
#                             interest_business  interest_creative  \
# age                                  0.022365           0.012513
# experience_years                    -0.037550          -0.023057
# openness                            -0.039466          -0.032376
# conscientiousness                   -0.035845          -0.034089
# extraversion                        -0.053561          -0.024869
# agreeableness                       -0.017186          -0.033996
# neuroticism                          0.054257           0.030094
# technical_skill                      0.117870          -0.216339
# data_reasoning_skill                 0.130480          -0.265018
# communication_skill                 -0.084734          -0.055276
# problem_solving_skill               -0.024738          -0.113835
# leadership_skill                    -0.011318          -0.036032
# creative_thinking_skill             -0.039653          -0.031139
# interest_technology                  0.031835          -0.228256
# interest_business                    1.000000          -0.184077
# interest_creative                   -0.184077           1.000000
# interest_health_social              -0.234550          -0.133651
# interest_research_academic          -0.188734          -0.280875
# risk_tolerance                       0.010740           0.009589
#
#                             interest_health_social  \
# age                                       0.005117
# experience_years                          0.001426
# openness                                 -0.006713
# conscientiousness                        -0.001405
# extraversion                              0.019761
# agreeableness                            -0.005190
# neuroticism                               0.013143
# technical_skill                          -0.156994
# data_reasoning_skill                     -0.114561
# communication_skill                       0.028864
# problem_solving_skill                    -0.026282
# leadership_skill                          0.028977
# creative_thinking_skill                  -0.007109
# interest_technology                      -0.246319
# interest_business                        -0.234550
# interest_creative                        -0.133651
# interest_health_social                    1.000000
# interest_research_academic                0.219193
# risk_tolerance                           -0.023681
#
#                             interest_research_academic  risk_tolerance
# age                                          -0.030942       -0.000849
# experience_years                              0.061394        0.008057
# openness                                      0.074745        0.001764
# conscientiousness                             0.049581       -0.003470
# extraversion                                  0.063608       -0.012575
# agreeableness                                 0.070478       -0.007328
# neuroticism                                  -0.076756        0.008726
# technical_skill                               0.061916        0.014422
# data_reasoning_skill                          0.156530        0.013729
# communication_skill                           0.151371        0.015926
# problem_solving_skill                         0.084921        0.000112
# leadership_skill                              0.044894        0.026876
# creative_thinking_skill                       0.071722       -0.018058
# interest_technology                           0.031146       -0.012772
# interest_business                            -0.188734        0.010740
# interest_creative                            -0.280875        0.009589
# interest_health_social                        0.219193       -0.023681
# interest_research_academic                    1.000000       -0.001609
# risk_tolerance                               -0.001609        1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,cmap="Blues")
plt.title('Correlation Heatmap (Numeric Features)')
plt.show()

# %%
from scipy.stats import chi2_contingency
target = "career_cluster"
categorical_col=df.select_dtypes(include=['object']).columns
results = []
for col in categorical_col:
    contingency_table = pd.crosstab(df[col], df[target])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    results.append({
        "feature": col,
        "chi_square": round(chi2, 3),
        "p_value": round(p, 6),
        "degrees_of_freedom": dof,
        "significant_at_0.05": p < 0.05
    })
chi_square_df = pd.DataFrame(results).sort_values("p_value")
chi_square_df
# Out:
#                  feature  chi_square   p_value  degrees_of_freedom  \
# 4         career_cluster   42594.000  0.000000                  36
# 3  preferred_environment       9.472  0.148730                   6
# 2   preferred_work_style       7.246  0.298717                   6
# 0        education_level       8.849  0.715758                  12
# 1         field_of_study      36.505  0.887453                  48
#
#    significant_at_0.05
# 4                 True
# 3                False
# 2                False
# 0                False
# 1                False

# %%
#Feature Engineering

df['openness_creative']= df['openness']   * df['creative_thinking_skill']
df['extraversion_lead']= df['extraversion'] * df['leadership_skill']

# %%
#Encoding
categorical_col=df.select_dtypes(include=['object']).columns
encode_col=categorical_col.drop('career_cluster')
df=pd.get_dummies(df,columns=encode_col,drop_first=True)

# %%
#Imbalance check
counts = df['career_cluster'].value_counts()
percent = df['career_cluster'].value_counts(normalize=True) * 100
imbalance_df = pd.DataFrame({
    'count': counts,
    'percentage': percent.round(2)
})
imbalance_df
# Out:
#                               count  percentage
# career_cluster
# Education & Social Impact      1081       15.23
# Technology & Engineering       1038       14.62
# Design & Creative Media        1032       14.54
# Healthcare & Life Sciences     1013       14.27
# Business & Management           999       14.07
# Entrepreneurship & Freelance    995       14.02
# Finance & Economics             941       13.26

# %%
imbalance_ratio = counts.max() / counts.min()
imbalance_ratio
# Out:
# np.float64(1.1487778958554729)

# %%
x=df.drop(columns='career_cluster')
y=df['career_cluster']

# %%
#Train-test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,stratify=y,random_state=42)
x_train
# Out:
#        age  experience_years  openness  conscientiousness  extraversion  \
# 1426  20.0               2.0       4.0                5.0           4.0
# 5288  24.0               5.0       4.0                5.0           4.0
# 5549  27.0               0.0       3.0                4.0           3.0
# 4260  26.0               0.0       3.0                3.0           1.0
# 2379  26.0               1.0       3.0                4.0           2.0
# ...    ...               ...       ...                ...           ...
# 5089  26.0               6.0       3.0                4.0           4.0
# 6798  27.0               1.0       3.0                5.0           3.0
# 844   24.0               2.0       3.0                3.0           3.0
# 3879  21.0               2.0       3.0                3.0           1.0
# 6877  25.0               5.0       4.0                4.0           2.0
#
#       agreeableness  neuroticism  technical_skill  data_reasoning_skill  \
# 1426            4.0          1.0              3.0                   1.0
# 5288            5.0          1.0              2.0                   3.0
# 5549            5.0          1.0              4.0                   4.0
# 4260            4.0          4.0              3.0                   3.0
# 2379            3.0          2.0              3.0                   2.0
# ...             ...          ...              ...                   ...
# 5089            3.0          1.0              4.0                   4.0
# 6798            5.0          1.0              2.0                   3.0
# 844             3.0          4.0              3.0                   2.0
# 3879            1.0          3.0              2.0                   3.0
# 6877            5.0          1.0              4.0                   4.0
#
#       communication_skill  ...  field_of_study_Business  \
# 1426                  2.0  ...                    False
# 5288                  4.0  ...                    False
# 5549                  4.0  ...                     True
# 4260                  3.0  ...                    False
# 2379                  3.0  ...                    False
# ...                   ...  ...                      ...
# 5089                  5.0  ...                    False
# 6798                  5.0  ...                    False
# 844                   3.0  ...                    False
# 3879                  4.0  ...                    False
# 6877                  4.0  ...                    False
#
#       field_of_study_Computer Science  field_of_study_Design  \
# 1426                            False                  False
# 5288                            False                  False
# 5549                            False                  False
# 4260                            False                  False
# 2379                            False                  False
# ...                               ...                    ...
# 5089                            False                  False
# 6798                            False                  False
# 844                             False                  False
# 3879                            False                  False
# 6877                            False                  False
#
#       field_of_study_Economics  field_of_study_Engineering  field_of_study_IT  \
# 1426                     False                       False              False
# 5288                      True                       False              False
# 5549                     False                       False              False
# 4260                     False                       False              False
# 2379                     False                       False              False
# ...                        ...                         ...                ...
# 5089                     False                       False              False
# 6798                     False                        True              False
# 844                      False                       False              False
# 3879                     False                       False              False
# 6877                     False                        True              False
#
#       field_of_study_Other  field_of_study_Psychology  \
# 1426                 False                      False
# 5288                 False                      False
# 5549                 False                      False
# 4260                 False                       True
# 2379                 False                      False
# ...                    ...                        ...
# 5089                 False                       True
# 6798                 False                      False
# 844                  False                       True
# 3879                 False                      False
# 6877                 False                      False
#
#       preferred_work_style_individual  preferred_environment_structured
# 1426                            False                             False
# 5288                             True                             False
# 5549                             True                              True
# 4260                            False                              True
# 2379                            False                              True
# ...                               ...                               ...
# 5089                            False                              True
# 6798                             True                             False
# 844                             False                              True
# 3879                            False                             False
# 6877                             True                              True
#
# [4969 rows x 33 columns]

# %%
#Model training
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=600, max_depth=11, max_features=0.35, min_samples_leaf=3, ccp_alpha=0.0001, random_state=42, n_jobs=-1)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['Entrepreneurship & Freelance', 'Business & Management',
#        'Healthcare & Life Sciences', ..., 'Education & Social Impact',
#        'Technology & Engineering', 'Healthcare & Life Sciences'],
#       shape=(2130,), dtype=object)

# %%
#Model evaluation
from sklearn.metrics import classification_report,accuracy_score
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.8366197183098592

# %%
# Get predictions for both sets
train_preds = model.predict(x_train)
test_preds = model.predict(x_test)

# Calculate accuracy
from sklearn.metrics import accuracy_score
train_acc = accuracy_score(y_train, train_preds)
test_acc = accuracy_score(y_test, test_preds)
print(f"Training Accuracy: {train_acc * 100:.2f}%")
print(f"Testing Accuracy: {test_acc * 100:.2f}%")
# Out:
# Training Accuracy: 90.92%
# Testing Accuracy: 83.66%

# %%
#Report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#                               precision    recall  f1-score   support
#
#        Business & Management       0.80      0.75      0.77       300
#      Design & Creative Media       0.97      0.97      0.97       310
#    Education & Social Impact       0.77      0.77      0.77       324
# Entrepreneurship & Freelance       0.84      0.81      0.83       299
#          Finance & Economics       0.77      0.78      0.78       282
#   Healthcare & Life Sciences       0.77      0.81      0.79       304
#     Technology & Engineering       0.93      0.95      0.94       311
#
#                     accuracy                           0.84      2130
#                    macro avg       0.84      0.84      0.84      2130
#                 weighted avg       0.84      0.84      0.84      2130

# %%
importances = pd.Series(model.feature_importances_,index=x_train.columns)
top_features = importances.nlargest(15)
plt.figure(figsize=(10, 6))
top_features.sort_values().plot(kind='barh')
plt.title("Top 15 Features")
plt.xlabel("Importance Score")
plt.show()

# %%
#Front end
import joblib
joblib.dump(model, 'career_model.joblib') # Save the trained model
feature_columns = list(x.columns)
joblib.dump(feature_columns, 'feature_columns.joblib') # Save feature columns
df_original = pd.read_csv('career.csv')
risk_tolerance_mapping = {'Low': 0, 'Medium': 1, 'High': 2}
joblib.dump(risk_tolerance_mapping, 'risk_tolerance_mapping.joblib')
print("\nFiles created:")
print("  - career_model.joblib")
print("  - feature_columns.joblib")
print("  - risk_tolerance_mapping.joblib")
# Out:
# Files created:
#   - career_model.joblib
#   - feature_columns.joblib
#   - risk_tolerance_mapping.joblib
